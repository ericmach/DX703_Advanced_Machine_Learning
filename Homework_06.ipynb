# %% [markdown]
# # Homework 6: N-Gram Language Models with the Brown Corpus
#
# ## Due: Midnight on October 12th @ Midnight (with 2-hour grace period) and worth 85 points.
#
# ## As announced, I'll not start to count late days until midnight on 10/13 (with same grace period).
#
# In this assignment you’ll practice **probabilistic language modeling (PLM)** by building N-Gram models that generate text. Along the way, you’ll develop the core pieces of a language model: estimating probabilities, calculating sentence likelihoods, and generating text with different strategies. The goal is to understand *how simple statistical models can produce coherent language*, and to explore refinements that make them more expressive.
#
# ### Learning Objectives
#
# * Build and compare **unigram, bigram, and trigram** language models.
# * Calculate **word and sentence probabilities** (in log-space) and use them to measure **perplexity**.
# * Implement **probability-based generation** methods, including temperature-scaled sampling.
# * Explore **beam search** as a way to generate higher-quality sentences.
#
# ### The four problems (high level)
#
# 1. **Problem 1 — N-Gram probabilities:**
#    Build unigram, bigram, and trigram models. Compute next-word probabilities in log space to avoid numerical underflow.
#
# 2. **Problem 2 — Sentence probability & perplexity:**
#    Define sentence probability, normalize for sentence length, and calculate perplexity as a measure of model quality.
#
# 3. **Problem 3 — Controlled generation:**
#    Implement temperature-controlled sampling to vary randomness in generated sentences. Compare low vs. high temperatures.
#
# 4. **Problem 4 — Beam search:**
#    Use perplexity to guide **beam search**, keeping track of the most likely candidate sentences at each step, and compare outputs to greedy generation.
#
# By the end, you’ll have a working N-Gram generator capable of producing reasonable and a solid understanding of how early probabilistic approaches to NLP laid the foundation for modern deep learning methods.

# %% [markdown]
# ### Recommended Workflow (Must Read!)
#
# One of the most important skills in machine learning is following a **disciplined workflow** when developing complex code. The basic idea is simple:
#
# 1. **Start small:** Write and test your code using a tiny subset of your dataset.
# 2. **Inspect your results:** Print out and examine intermediate outputs to verify that each step behaves as expected.
# 3. **Iterate and tune:** Adjust hyperparameters and continue testing, gradually increasing the subset size as needed.
# 4. **Scale up:** Once you are confident your code is bug-free and your hyperparameters are roughly correct, run it on the **full dataset** to obtain your final results.
#
# If you don’t have sufficient computing resources for a full run, use **as large a subset as practical** — provided you’ve begun early enough to allow for multiple iterations.
#
#
# To help you follow this workflow in this homework, I’ve included a variable `num_sentences` that controls how many sentences are used from the shuffled Brown Corpus.
#
# I recommend the following progression:
#
# * **Step 1:** Begin with `num_sentences = 10` to debug and print out intermediate data structures (such as dictionaries) to confirm that your code works as expected.
# * **Step 2:** Increase to `num_sentences = 100` to verify correctness and complete most of the homework efficiently.
# * **Step 3:** Finally, if possible, run with the full dataset (`num_sentences = 57_340`), or as large a subset as your resources allow, to answer the graded questions.
#
#
# There are 9 problems in this homework, each worth 9 points each, and you get 4 points free if you otherwise complete the homework.

# %% [markdown]
# #### Useful Imports (add more as needed)

# %%
import math
import re
import string
import random
import spacy
import numpy as np
import pandas as pd
from tqdm import tqdm
from matplotlib import pyplot as plt
from collections import Counter

random.seed(42)

# %%
'''
Reconstruct a human-readable sentence from tokens.
- Capitalize the first token (after removing <s>).
- Attach any token in string.punctuation with no preceding space.
- Attach tokens starting with an apostrophe (e.g., "'s", "'ll") with no space.
- Capitalize standalone 'i' and 'god' wherever they appear.
- If the last token is '.', '?', or '!', attach it without a space.
- Ignore boundary markers <s> and </s> if present.
Returns the sentence string and also prints it depending on flag parameter.
'''

def print_sentence(tokens, do_print=True):

    if not tokens:
        print("")
        return ""

    # Drop boundary markers if present
    start = 1 if tokens and tokens[0] == "<s>" else 0
    end = -1 if tokens and tokens[-1] == "</s>" else len(tokens)
    core = tokens[start:end]

    if not core:
        print("")
        return ""

    # Capitalize first token
    out = core[0].capitalize()

    # Process remaining tokens with spacing rules
    for i, t in enumerate(core[1:], start=1):
        is_last = (i == len(core) - 1)

        # Last-token punctuation rule
        if is_last and t in {".", "?", "!"}:
            out += t
            continue

        # General punctuation attaches with no space (e.g., ',', ':', ';', ')', etc.)
        if t in string.punctuation:
            out += t
            continue

        # Apostrophe-start tokens like "'s", "'d", "'ll"
        if t.startswith("'"):
            out += t
            continue

        # Capitalize special standalone words
        if t.lower() in {"i", "god"}:
            out += " " + t.capitalize()
            continue

        # Default: add a space before normal words
        out += " " + t

    if do_print:
        print(out)
    return out

# %% [markdown]
# ### Read in the list of all sentences in the Brown Corpus and process using SPaCy.

# %%
# Must do this the first time to get the Natural Language ToolKit
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)

# %%
import nltk
from nltk.corpus import brown
import spacy

nltk.download('brown')

# Get all Brown corpus sentences as raw text
# Brown is organized into categories, we flatten it into one list of sentences and shuffle
# so we can create a shorter list for testing

brown_texts = [" ".join(sent) for sent in brown.sents()]

random.shuffle(brown_texts)

# Brown has 57_340 sentences, set `num_sentences` to 1000 or smaller for testing

# num_sentences = 57_340
num_sentences = 57340                          # <<<<<=====    Here is where you can change the size of the dataset

brown_texts = brown_texts[:num_sentences]

# Load spaCy English pipeline
nlp = spacy.load("en_core_web_sm")

# Process with spaCy: tokenize + sentencize
docs = list(nlp.pipe(brown_texts, disable=["ner", "tagger", "parser"]))

# Each doc is one sentence; extract tokens and add beginning and ending tokens <s> ... </s>
tokenized_sentences = [ ['<s>'] + [token.text.lower() for token in doc if not token.is_space] + ['</s>'] for doc in docs ]
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/lemmatizer.py:188: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %% [markdown]
# #### If you have trouble downloading this...
#
#
# I have uploaded a file `brown_sentences.txt` to a Google Drive folder which anyone with the link can read, just
# uncomment the code in the next cell and run it:

# %%
'''
import re, requests, random, spacy

# Paste the shared Drive link (no need to change anything else)
link = "https://drive.google.com/file/d/1f_BkNDF0ny11Tn4D4jsOoXhgPSUCHKlf/view?usp=drive_link"

# --- Convert to direct download URL ---
def get_direct_download_url(link):
    match = re.search(r"/d/([a-zA-Z0-9_-]+)", link) or re.search(r"id=([a-zA-Z0-9_-]+)", link)
    if not match:
        raise ValueError("Could not extract file ID from the link.")
    file_id = match.group(1)
    return f"https://drive.google.com/uc?export=download&id={file_id}"

url = get_direct_download_url(link)

# --- Download and prepare the text ---
response = requests.get(url)
lines = response.text.strip().split("\n")

random.shuffle(lines)


# Etc as before
'''

# %%
print("Number of sentences:", len(tokenized_sentences))
print("First sentence:      ",end='')
print_sentence(tokenized_sentences[0])
print("Tokenized sentence: ",end='')
print(tokenized_sentences[0])
# Out:
# Number of sentences: 57340
# First sentence:      The hearst men say that if hearst is nominated, he and his immediate friends will contribute to the democratic national committee the sum of$ 1,500,000.
# Tokenized sentence: ['<s>', 'the', 'hearst', 'men', 'say', 'that', 'if', 'hearst', 'is', 'nominated', ',', 'he', 'and', 'his', 'immediate', 'friends', 'will', 'contribute', 'to', 'the', 'democratic', 'national', 'committee', 'the', 'sum', 'of', '$', '1,500,000', '.', '</s>']

# %% [markdown]
# ### A Little EDA....

# %%
# Flatten tokens (exclude spaces)
all_tokens = [tok.text.lower() for sent in docs for tok in sent if not tok.is_space]

# Define "word": alphabetic, or alphabetic after removing internal apostrophes
def is_word(tok):
    s = tok.text
    return s.isalpha() or s.replace("'", "").isalpha()

# Extract words using the definition above
words = [
    tok.text.lower()
    for sent in docs
    for tok in sent
    if not tok.is_space and is_word(tok)
]

# Counts
num_chars = sum(len(s) for s in brown_texts)   # or len(text) if you started from one big text
num_tokens = len(all_tokens)
num_unique_tokens = len(set(all_tokens))
num_sentences = len(docs)
num_words = len(words)
num_unique_words = len(set(words))

print(f"Total number of characters in the text: {num_chars:,}")
print(f"Total number of tokens:    {num_tokens:,}")
print(f"Number of unique tokens:   {num_unique_tokens:,}")
print(f"Total number of sentences: {num_sentences:,}")
print(f"Total number of words:     {num_words:,}")
print(f"Number of unique words:    {num_unique_words:,}")

# Frequencies
word_counts = Counter(words)
most_common_words = word_counts.most_common()

# Top 10
print("\nTop 10 words:")
for token, freq in most_common_words[:10]:
    print(f"{token:<15}: {freq:,}")

# Bottom 10
print("\nBottom 10 words:")
for token, freq in most_common_words[-10:]:
    print(f"{token:<15}: {freq:,}")
# Out:
# Total number of characters in the text: 6,069,734
# Total number of tokens:    1,198,833
# Number of unique tokens:   43,320
# Total number of sentences: 57,340
# Total number of words:     1,017,681
# Number of unique words:    41,455
#
# Top 10 words:
# the            : 70,003
# of             : 36,473
# and            : 28,916
# to             : 26,241
# a              : 23,259
# in             : 21,419
# that           : 10,789
# is             : 10,206
# was            : 9,969
# he             : 9,801
#
# Bottom 10 words:
# mettwurst      : 1
# bratwurst      : 1
# bockwurst      : 1
# knackwurst     : 1
# pepperoni      : 1
# blutwurst      : 1
# burford        : 1
# byer           : 1
# barium         : 1
# vrilium        : 1

# %% [markdown]
# ### Digression: Zipf's Law
#
# Zipf's Law is an empirical regularity of natural language:
# if you rank words by their frequency in a corpus, the frequency \( f(r) \) of the word at rank \( r \) is approximately inversely proportional to its rank:
#
# $$
# f(r) \propto \frac{1}{r^k}
# $$
#
# where $ r = 1, 2, 3, \dots $ is the rank of a word (1 = most frequent), and $ k \approx 1 $.
#
# - The most common words (e.g., *the*, *of*, *and*) occur very often.
# - A handful of mid-ranked words occur moderately often.
# - The vast majority of words occur rarely.
#
# On a **log–log plot** of frequency vs. rank, this relationship appears as a straight line with slope \(-k\).
# For natural language, empirical studies show that $k \approx 1$, which is why we plot below a reference line with slope $-1$ to compare against real corpus data.
#
#
# **Why this matters:** Because most words are rare, language models must use techniques like **smoothing, subword modeling, or embeddings** to handle sparsity and represent meaning effectively.

# %%
# Frequencies sorted by rank
freqs = np.array([freq for token, freq in word_counts.most_common()])
ranks = np.arange(1, len(freqs) + 1)

plt.figure(figsize=(8, 5))
plt.plot(ranks, freqs, label="Corpus data")

# Reference line: slope = -1 (Zipf’s law)
# Match scale by anchoring at the first frequency
ref_line = freqs[0] / ranks
plt.plot(ranks, ref_line, "--", label="Reference slope = -1")

plt.xscale("log")
plt.yscale("log")
plt.title("Token Frequencies vs. Rank (Zipf’s Law)")
plt.xlabel("Rank of token")
plt.ylabel("Frequency of token")
plt.grid(True, which="both", ls="--", alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# Compute sentence lengths from spaCy docs
sentence_lengths = [len([tok for tok in sent if not tok.is_space]) for sent in docs]

# Plot histogram
plt.figure(figsize=(8, 4))
plt.hist(
    sentence_lengths,
    bins=range(1, max(sentence_lengths) + 2),
    color="skyblue",
    edgecolor="black"
)
plt.title("Histogram of Sentence Lengths")
plt.xlabel("Sentence length (in tokens)")
plt.ylabel("Number of sentences")
plt.tight_layout()
plt.show()

print(f"Average sentence length: {sum(sentence_lengths)/len(sentence_lengths):.2f} tokens")
print(f"Max sentence length:     {max(sentence_lengths)} tokens")
# Out:
# Average sentence length: 20.91 tokens
# Max sentence length:     182 tokens

# %% [markdown]
# ## Problem One — Build the PLM (bigrams & trigrams)
#
# For this problem, you must adapt (mostly cut-and-paste) the code from this week’s Coding Notebook to the new dataset. You are using a trigram model as well as bigrams but your professor has written code that should mostly work for any N.
#
# We provide a pre-processed dataset above, with sentences already tokenized and enclosed in the boundary tokens `<s>` and `</s>`.
#
# **Set `num_sentences=10` to start!**
#
# **ToDo:**
#
# **A.** Build N-grams for N = 2, 3
#
# - Compute all bigrams and trigrams over the tokenized sentences (boundary tokens included).
#
# **B.** Create a dictionary mapping left-contexts to next-word lists
#
# - For each N, map each context (length N−1) to a list of next tokens (allow duplicates so frequency = count).
#
# **C.** Convert to (log) probability distributions
#
# - Turn each context’s next-word list into a distribution of log-probabilities (see **Appendix Two**).
#
# **D.** Create the Probability Language Model (PLM)
#
# - Create a dictionary `get_next_word` with:
#
#     - Key: left context (tuple of 1 token for bigrams; 2 tokens for trigrams).
#
#     - Values: nested dictionary mapping next tokens to log-probabilities `{next_token: log_prob, ...}`.
#
# - Create a **single dictionary** (since bigrams and trigrams have a left context of different lengths, and they won't get confused in the dictionary).
#
#
# **E.** Set the variable `num_sentences = 10` and do a sanity check by displaying the distribution for the bigram contexts e.g., `('<s>',)` and `('the',)` and a trigram context `('<s>','the')`. If for some reason these are not present, increase the number of sentences slightly.
#
# **F.**  Generate 5 next words for each of the 3 examples in the previous part.
#
# **Then answer the graded questions.**

# %%
# Your code here (add as many cells as you need)
from collections import defaultdict
import math

def build_ngrams(tokenized_sentences, n):
    ngram_map = defaultdict(list)
    for sent in tokenized_sentences:
        for i in range(len(sent) - n + 1):
            context = tuple(sent[i:i + n - 1])
            next_token = sent[i + n - 1]
            ngram_map[context].append(next_token)
    return ngram_map

def compute_log_probs(ngram_map):
    plm = {}
    for context, next_words in ngram_map.items():
        counts = Counter(next_words)
        total = sum(counts.values())
        probs = {w: math.log(c / total) for w, c in counts.items()}
        plm[context] = probs
    return plm

bigram_map = build_ngrams(tokenized_sentences, n=2)
trigram_map = build_ngrams(tokenized_sentences, n=3)

bigram_probs = compute_log_probs(bigram_map)
trigram_probs = compute_log_probs(trigram_map)

get_next_word = {**bigram_probs, **trigram_probs}


sample_contexts = [
    ('<s>',),
    ('the',),
    ('<s>', 'the')
]

for ctx in sample_contexts:
    if ctx in get_next_word:
        print(f"\nContext {ctx}:")
        for w, lp in get_next_word[ctx].items():
            print(f"  {w:12s} {lp: .3f}")
    else:
        print(f"\nContext {ctx} not found in PLM.")
# Out:
# Context ('<s>',):
#   the          -2.124
#   what         -5.155
#   god          -8.249
#   replied      -10.264
#   another      -6.212
#   anti         -9.858
#   his          -4.781
#   said         -8.124
#   never        -7.699
#   unless       -8.472
#   `            -2.622
#   a            -3.924
#   success      -9.165
#   be           -7.779
#   from         -5.933
#   every        -6.986
#   incidentally -9.165
#   maybe        -7.128
#   today        -7.173
#   it           -3.286
#   garth        -9.570
#   there        -4.177
#   he           -2.933
#   later        -7.268
#   just         -6.372
#   i            -3.626
#   to           -4.895
#   this         -3.921
#   ask          -8.760
#   but          -3.694
#   in           -3.489
#   time         -7.738
#   ritchie      -10.957
#   grosse       -9.011
#   dives        -10.957
#   during       -6.066
#   thomas       -8.124
#   or           -6.265
#   and          -3.925
#   (            -5.090
#   gloomy       -10.957
#   product      -10.264
#   we           -4.524
#   with         -5.392
#   payment      -10.957
#   she          -4.107
#   if           -4.413
#   now          -5.519
#   palfrey      -8.654
#   too          -7.625
#   when         -4.631
#   meynell      -10.264
#   very         -7.912
#   269          -10.957
#   morale       -10.957
#   someone      -8.124
#   slowly       -9.011
#   10           -9.165
#   these        -5.113
#   at           -4.968
#   nassau       -10.957
#   no           -5.396
#   presentable  -10.957
#   after        -5.451
#   susan        -8.318
#   hatless      -10.957
#   so           -5.563
#   is           -6.708
#   gross        -8.559
#   hot          -9.011
#   yet          -5.939
#   whereas      -8.559
#   shayne       -8.066
#   2            -6.653
#   any          -7.293
#   being        -8.184
#   therapist    -10.957
#   then         -5.082
#   one          -4.955
#   perhaps      -6.446
#   beyond       -8.249
#   judges       -10.957
#   according    -7.589
#   pat          -8.318
#   ready        -10.957
#   everything   -7.961
#   some         -5.619
#   mrs.         -6.238
#   their        -6.212
#   once         -6.562
#   theorem      -10.264
#   insomnia     -10.957
#   rector       -8.654
#   above        -7.912
#   attendance   -9.858
#   mckinley     -10.957
#   needless     -9.165
#   others       -7.373
#   her          -5.933
#   accordingly  -8.012
#   further      -7.779
#   below        -8.472
#   you          -5.038
#   for          -4.525
#   kate         -8.472
#   each         -6.145
#   annapolis    -9.858
#   willow       -10.957
#   abnormal     -10.957
#   they         -4.123
#   issue        -9.011
#   even         -5.720
#   forebearing  -10.957
#   work         -9.011
#   halleck      -10.264
#   on           -5.195
#   great        -9.165
#   did          -7.523
#   west         -8.760
#   joseph       -9.347
#   arthur       -9.165
#   those        -6.708
#   an           -5.720
#   --           -5.568
#   suppose      -7.912
#   chicago      -8.654
#   inheritance  -10.957
#   jagged       -10.957
#   here         -6.037
#   whenever     -8.318
#   squeezing    -10.957
#   benson       -9.011
#   mines        -9.011
#   woodruff     -9.165
#   cousin       -8.877
#   red          -8.392
#   many         -6.284
#   that         -5.006
#   behind       -8.472
#   bonner       -10.957
#   object       -10.957
#   ernie        -8.760
#   recently     -8.249
#   how          -5.907
#   diversity    -10.264
#   as           -4.676
#   however      -5.792
#   among        -6.879
#   family       -9.011
#   opposite     -9.858
#   nearly       -9.011
#   generally    -8.392
#   friends      -10.957
#   until        -7.625
#   orlando      -10.264
#   only         -6.247
#   3            -7.065
#   mikoyan      -10.957
#   charge       -10.957
#   although     -6.153
#   tests        -9.858
#   all          -5.541
#   three        -7.401
#   honor        -10.264
#   greases      -10.957
#   doc          -9.570
#   whoever      -8.877
#   not          -5.907
#   phil         -7.430
#   indeed       -7.107
#   petitioner   -8.559
#   alex         -8.760
#   let          -6.362
#   quasimodo    -10.957
#   thus         -5.827
#   alec         -8.184
#   wingback     -10.957
#   oersted      -9.347
#   sol          -10.957
#   sssshoo      -10.957
#   unconsciously -10.957
#   plank        -10.957
#   more         -6.639
#   do           -6.322
#   early        -8.066
#   finding      -9.347
#   try          -8.472
#   scrub        -10.957
#   critical     -10.264
#   efforts      -9.858
#   catherwood   -10.957
#   will         -7.866
#   participants -10.957
#   legislators  -9.570
#   serve        -9.570
#   commands     -10.957
#   would        -7.491
#   pauling      -9.570
#   by           -5.679
#   such         -6.229
#   apparently   -7.821
#   except       -8.559
#   large        -8.760
#   since        -5.839
#   though       -6.798
#   watson       -7.625
#   glad         -10.264
#   sometimes    -6.896
#   insurance    -10.264
#   dickens      -9.347
#   providing    -9.858
#   )            -5.769
#   5            -7.866
#   indirectly   -10.957
#   back         -8.559
#   had          -7.460
#   pass         -9.858
#   my           -6.275
#   under        -6.949
#   thirty       -8.559
#   over         -7.589
#   throughout   -8.012
#   smu          -10.957
#   carbon       -10.957
#   claims       -10.264
#   similarly    -8.124
#   sewing       -10.957
#   are          -7.243
#   check        -8.392
#   brief        -9.858
#   rookie       -9.858
#   unpublished  -10.957
#   mr.          -5.472
#   cta          -10.957
#   several      -7.346
#   two          -6.382
#   feeling      -9.570
#   finally      -6.896
#   pete         -8.472
#   war          -9.858
#   regulars     -10.957
#   against      -8.760
#   study        -9.570
#   usually      -8.066
#   privately    -9.858
#   still        -7.086
#   blue         -8.877
#   mission      -9.347
#   calhoun      -10.264
#   dancers      -10.957
#   precious     -10.957
#   montero      -9.347
#   meanwhile    -7.866
#   snowballs    -10.957
#   data         -9.165
#   america      -8.877
#   anyone       -8.559
#   .            -6.968
#   position     -9.570
#   various      -9.347
#   brumidi      -10.957
#   stay         -10.957
#   include      -10.264
#   distances    -10.264
#   yours        -10.957
#   investigation -10.957
#   opponents    -10.957
#   vandiver     -10.264
#   engages      -10.957
#   about        -7.196
#   most         -6.372
#   arms         -10.957
#   sam          -8.654
#   both         -6.526
#   its          -6.587
#   charlie      -8.249
#   whether      -7.589
#   requests     -9.858
#   calls        -10.264
#   patients     -10.957
#   questioned   -10.957
#   telephone    -9.347
#   hansen       -9.570
#   while        -6.161
#   rachel       -7.821
#   secretary    -8.654
#   start        -8.472
#   blockade     -9.858
#   nor          -7.319
#   drug         -8.066
#   couperin     -10.264
#   goodby       -10.957
#   fred         -9.570
#   solomon      -10.264
#   like         -6.914
#   balanced     -10.957
#   well         -6.968
#   therefore    -6.949
#   format       -9.570
#   also         -6.680
#   replacement  -10.957
#   nothing      -7.128
#   denver       -9.858
#   state        -8.184
#   hey          -10.957
#   consider     -7.961
#   molten       -10.957
#   modern       -8.472
#   starting     -9.165
#   gaining      -10.957
#   nowhere      -9.165
#   colquitt     -10.957
#   richard      -8.184
#   harbor       -10.957
#   pompeii      -9.858
#   galli        -10.957
#   first        -6.737
#   maris        -9.011
#   glance       -10.957
#   up           -8.559
#   pretend      -10.957
#   serves       -10.957
#   winston      -8.124
#   already      -8.124
#   henrietta    -8.760
#   whispers     -10.957
#   pp           -9.570
#   rather       -7.779
#   rabb         -10.957
#   thompson     -10.264
#   dr.          -7.107
#   mike         -7.268
#   eileen       -9.011
#   practices    -10.264
#   your         -7.625
#   ahah         -10.957
#   writers      -9.858
#   pitchers     -10.264
#   make         -7.912
#   inscribed    -10.957
#   eric         -10.957
#   h.l.         -10.957
#   shea         -9.570
#   victor       -9.570
#   irradiation  -10.957
#   lucy         -8.559
#   aug.         -10.957
#   uniform      -10.957
#   verbal       -10.957
#   koenigsberg  -10.957
#   small        -8.760
#   get          -8.654
#   concerning   -9.858
#   mortality    -10.957
#   why          -6.424
#   part         -7.821
#   grabbing     -10.957
#   lawrence     -8.877
#   1            -7.107
#   out          -7.491
#   proof        -8.877
#   oak          -10.264
#   shakespeare  -8.877
#   miss         -7.025
#   moll         -10.957
#   thayer       -10.264
#   cultural     -10.957
#   eli          -10.957
#   little       -8.472
#   charles      -8.559
#   perfect      -10.264
#   burnham      -10.957
#   upon         -8.066
#   nineteen     -10.264
#   club         -10.957
#   respect      -10.264
#   neither      -7.430
#   lacking      -9.011
#   through      -7.661
#   often        -7.866
#   mercer       -8.066
#   noting       -9.347
#   keep         -8.472
#   alf          -10.957
#   louise       -10.264
#   federal      -9.165
#   next         -7.460
#   underlying   -9.858
#   national     -8.877
#   theocracy    -10.957
#   6            -8.124
#   action       -9.858
#   method       -9.858
#   local        -8.760
#   deputy       -10.264
#   builder      -10.957
#   home         -9.347
#   ritter       -9.570
#   hieronymus   -10.957
#   where        -6.862
#   editor       -9.858
#   apropos      -10.957
#   blackman     -9.347
#   our          -6.526
#   experimental -9.347
#   better       -8.877
#   please       -9.165
#   shot         -10.264
#   because      -6.767
#   mullins      -9.858
#   *            -9.347
#   conrad       -9.858
#   rudyard      -10.957
#   actually     -7.346
#   maude        -8.559
#   arriving     -9.858
#   karen        -10.264
#   resourceful  -10.957
#   boats        -9.858
#   intercede    -10.957
#   willie       -9.570
#   cut          -8.559
#   give         -8.877
#   new          -6.949
#   wally        -9.570
#   taking       -8.392
#   admiralty    -10.957
#   examples     -9.165
#   $            -9.347
#   361          -10.957
#   almost       -7.699
#   bobby        -8.654
#   blood        -9.347
#   metabolic    -10.957
#   kearton      -9.347
#   elisha       -10.957
#   business     -9.165
#   nine         -9.347
#   nonetheless  -9.570
#   douglas      -9.858
#   synthetic    -10.957
#   dorothy      -10.957
#   measurements -9.347
#   ease         -10.957
#   shortage     -10.264
#   woman        -10.957
#   andrus       -10.957
#   hindemith    -10.957
#   mine         -9.858
#   thornburg    -9.347
#   military     -9.011
#   of           -5.901
#   wilmette     -10.957
#   between      -8.318
#   negroes      -9.570
#   tommy        -9.011
#   television   -10.264
#   aristide     -10.957
#   pictures     -9.570
#   officers     -10.957
#   can          -7.738
#   need         -9.347
#   total        -9.858
#   vincent      -9.858
#   looks        -10.957
#   travel       -9.570
#   corporations -9.347
#   come         -8.559
#   gloria       -10.957
#   incest       -10.957
#   everyone     -8.012
#   gun          -8.559
#   thoroughly   -10.264
#   salary       -10.264
#   currency     -9.347
#   stained      -10.264
#   fads         -10.957
#   alaska       -10.957
#   living       -9.347
#   numbers      -9.347
#   years        -9.011
#   loan         -10.264
#   boatmen      -10.957
#   lewis        -8.472
#   ma           -9.858
#   spectra      -9.570
#   af           -8.184
#   something    -7.661
#   abelson      -10.957
#   eddie        -8.760
#   quiet        -10.957
#   retirement   -10.264
#   john         -6.968
#   houston      -10.264
#   commentary   -10.957
#   l'institut   -10.957
#   matsuo       -8.184
#   daniel       -9.011
#   hand         -9.570
#   haying       -10.957
#   stroked      -10.957
#   juet         -10.264
#   speaker      -10.957
#   accidental   -10.957
#   peace        -9.347
#   mobile       -9.858
#   bandstand    -10.957
#   cause        -10.264
#   lemon        -10.957
#   happily      -10.957
#   student      -8.760
#   patchen      -9.165
#   spraying     -10.957
#   consequently -8.318
#   wolfe        -10.957
#   copernicus   -9.347
#   barber       -10.264
#   poirot       -10.957
#   religious    -9.570
#   stowey       -10.957
#   figures      -9.570
#   facts        -10.957
#   sarason      -10.957
#   withholding  -10.957
#   antoine      -10.957
#   getting      -9.165
#   change       -9.858
#   blistered    -10.957
#   staley       -10.957
#   before       -6.782
#   resistance   -10.957
#   last         -7.491
#   companies    -10.957
#   elaine       -9.011
#   beccaria     -10.957
#   mitchell     -9.165
#   joanne       -10.957
#   adam         -8.472
#   plays        -10.957
#   land         -8.760
#   fiberglas    -10.957
#   again        -7.243
#   lucky        -10.957
#   measurement  -10.957
#   interfaith   -10.264
#   pressing     -9.858
#   ex           -10.264
#   ''           -6.468
#   yes          -7.373
#   similar      -8.559
#   clams        -10.957
#   wherever     -9.858
#   dan          -9.011
#   put          -8.654
#   sandman      -9.570
#   parkway      -10.957
#   repnin       -10.957
#   bisque       -9.570
#   instead      -7.086
#   them         -9.858
#   electricity  -10.957
#   self         -9.858
#   control      -9.570
#   congratulations -10.264
#   significantly -10.264
#   responses    -10.957
#   pugh         -10.957
#   fiscal       -9.570
#   jobs         -10.264
#   increased    -9.570
#   ,            -8.472
#   steak        -10.957
#   troubled     -10.957
#   duclos       -9.858
#   certainly    -7.661
#   poor         -8.654
#   outside      -8.012
#   sizzling     -10.957
#   push         -9.858
#   anne         -8.654
#   use          -7.661
#   seafood      -10.957
#   rabbits      -10.957
#   victim       -10.957
#   communist    -9.570
#   tradition    -10.957
#   morgan       -8.124
#   packing      -10.264
#   decanting    -10.957
#   julia        -9.570
#   lee          -9.570
#   who          -7.268
#   doubtless    -10.957
#   lublin       -9.858
#   teeth        -10.957
#   second       -7.779
#   was          -7.293
#   doctors      -10.957
#   manthey      -10.957
#   stilts       -10.264
#   weekly       -10.957
#   proclamation -10.957
#   hurt         -10.957
#   gen.         -9.347
#   within       -7.319
#   besides      -7.243
#   rod          -9.570
#   olivetti     -10.957
#   styka        -9.165
#   fairchild    -10.957
#   robinson     -9.165
#   other        -6.653
#   cambodia     -10.264
#   crystal      -10.264
#   operating    -9.347
#   simple       -9.347
#   personally   -9.347
#   docherty     -9.858
#   pitcher      -10.957
#   terms        -10.264
#   diversification -10.957
#   walton       -9.570
#   otherwise    -7.866
#   hoag         -8.654
#   experience   -9.570
#   specific     -9.347
#   methods      -10.264
#   betting      -10.957
#   cleveland    -9.858
#   remove       -9.011
#   shape        -10.957
#   freshman     -10.957
#   ultraviolet  -10.957
#   roll         -10.264
#   salaries     -10.957
#   families     -9.570
#   general      -8.249
#   led          -10.264
#   attributes   -10.957
#   research     -8.472
#   attempts     -10.264
#   moreover     -6.723
#   isaac        -9.858
#   poet         -8.392
#   incorporated -10.957
#   thorpe       -10.957
#   carrying     -10.957
#   simmer       -9.858
#   section      -8.760
#   blanched     -10.957
#   organification -10.957
#   rousseau     -9.165
#   du           -9.165
#   winter       -10.264
#   housewives   -10.957
#   cook         -10.264
#   s.k.         -10.957
#   voter        -10.957
#   nick         -9.165
#   professor    -9.570
#   hiroshima    -10.957
#   ejaculated   -10.957
#   nuclear      -9.570
#   see          -7.912
#   ch           -10.264
#   far          -8.654
#   rank         -10.264
#   quite        -8.760
#   hudson       -8.760
#   johnny       -9.165
#   take         -7.912
#   simultaneous -10.957
#   gradual      -10.957
#   uninhibited  -10.957
#   forty        -8.877
#   question     -9.570
#   hence        -7.460
#   ekstrohm     -8.124
#   have         -7.346
#   scholarship  -10.957
#   thankful     -10.957
#   stations     -10.957
#   botulinal    -10.957
#   stick        -10.957
#   officials    -9.858
#   men          -8.124
#   dealers      -10.264
#   troopers     -10.957
#   tessie       -10.264
#   communication -9.858
#   without      -7.319
#   ah           -9.165
#   does         -7.625
#   less         -8.472
#   subgroups    -10.264
#   truman       -10.957
#   tva          -10.957
#   hardly       -9.011
#   helva        -9.011
#   fractions    -10.957
#   ryan         -9.165
#   split        -10.957
#   warsaw       -9.570
#   government   -9.570
#   go           -8.877
#   straighten   -10.957
#   loomis       -10.264
#   hell         -9.165
#   william      -7.738
#   always       -9.011
#   circumstances -10.264
#   linda        -8.760
#   subject      -9.858
#   minneapolis  -9.858
#   reactionary  -10.957
#   despite      -7.346
#   contract     -10.957
#   democratic   -9.858
#   watching     -10.264
#   moreland     -9.011
#   obviously    -7.661
#   chico        -10.957
#   nervousness  -10.957
#   similarities -10.957
#   theoretical  -9.858
#   should       -7.912
#   off          -9.011
#   lincoln      -9.165
#   undertaken   -10.957
#   cascading    -9.858
#   homemade     -10.264
#   spread       -9.570
#   pale         -10.957
#   curt         -8.012
#   people       -8.012
#   san          -9.570
#   marlin       -10.264
#   whose        -10.264
#   mercifully   -10.957
#   prisoners    -10.957
#   nodding      -10.957
#   spirit       -10.957
#   krim         -9.165
#   keith        -9.011
#   certain      -8.877
#   ruth         -10.264
#   kitty        -10.264
#   soccer       -10.957
#   '            -7.866
#   krist        -10.957
#   samuel       -9.858
#   fuchs        -10.957
#   glendora     -9.347
#   damn         -9.858
#   giffen       -8.760
#   madden       -8.760
#   draper       -10.957
#   drawing      -10.264
#   plant        -10.264
#   trenton      -10.264
#   joined       -10.957
#   angry        -9.858
#   marcellus    -10.957
#   dynafac      -10.957
#   microscopically -9.165
#   individual   -9.011
#   inspiring    -10.957
#   soaring      -10.957
#   turning      -8.392
#   sources      -9.165
#   oh           -7.523
#   results      -8.760
#   deegan       -9.858
#   helion       -9.570
#   kitti        -9.347
#   woven        -10.264
#   set          -9.011
#   player       -9.011
#   hospital     -10.264
#   regardless   -9.165
#   originals    -10.957
#   law          -10.264
#   physiologically -10.957
#   low          -9.858
#   article      -9.347
#   philadelphia -9.347
#   ambushes     -10.957
#   bruises      -10.264
#   help         -9.347
#   aligning     -10.957
#   rev          -8.760
#   spear        -10.957
#   seeing       -8.472
#   construction -9.347
#   workshops    -10.957
#   problems     -9.011
#   simply       -9.347
#   whaddya      -10.957
#   systemic     -10.264
#   hirey        -10.957
#   9            -9.347
#   profile      -10.957
#   love         -9.570
#   dimensions   -10.264
#   resignedly   -10.957
#   pam          -10.264
#   intangible   -10.957
#   nobody       -7.912
#   max          -10.957
#   straightening -10.264
#   facilities   -10.264
#   public       -8.760
#   save         -10.264
#   eight        -8.877
#   oddly        -9.858
#   magnum       -10.264
#   pioneer      -10.957
#   workers      -10.957
#   either       -8.654
#   economically -10.957
#   high         -8.249
#   conservation -10.957
#   finot        -10.957
#   plants       -10.264
#   kennedy      -9.347
#   moore        -10.957
#   sent         -10.264
#   dried        -10.264
#   loneliness   -10.957
#   residential  -9.570
#   reaching     -9.347
#   bill         -8.318
#   miriam       -9.011
#   baseball     -9.858
#   breeding     -10.264
#   feelings     -10.957
#   equipment    -9.858
#   henry        -9.011
#   associated   -10.957
#   sherman      -8.877
#   jaggers      -10.957
#   professionally -10.957
#   subsystems   -10.957
#   temperature  -9.570
#   fortunately  -8.184
#   austin       -9.011
#   cow          -10.957
#   together     -9.165
#   brandon      -10.957
#   suddenly     -7.821
#   underground  -10.957
#   via          -10.957
#   ants         -10.957
#   formula      -10.957
#   vehicle      -10.264
#   dice         -10.264
#   geneva       -9.858
#   samples      -9.570
#   few          -8.124
#   furthermore  -7.346
#   initially    -9.165
#   dark         -10.264
#   los          -9.858
#   esther       -9.858
#   tell         -8.760
#   guilford     -9.858
#   meeting      -9.347
#   sex          -10.264
#   somebody     -8.559
#   five         -7.821
#   adverbial    -10.957
#   body         -10.264
#   water        -8.760
#   sameness     -10.264
#   s.           -10.264
#   methyl       -10.957
#   louis        -9.011
#   marty        -8.760
#   apart        -8.654
#   across       -8.760
#   bake         -9.011
#   sturley      -9.347
#   down         -9.347
#   florida      -10.957
#   asked        -8.184
#   kansas       -9.570
#   o'banion     -8.877
#   soviet       -10.264
#   jones        -8.654
#   tenure       -10.264
#   swadesh      -10.264
#   frank        -9.858
#   interruptions -10.957
#   songs        -10.957
#   socialist    -10.957
#   colors       -10.264
#   greasy       -10.264
#   invercalt    -10.957
#   sheets       -10.264
#   dogs         -10.264
#   husbandry    -10.957
#   obesity      -10.957
#   employers    -10.957
#   preserving   -9.858
#   jazz         -9.347
#   reduced      -10.264
#   wilson       -8.472
#   pip          -9.347
#   harvey       -9.347
#   find         -9.570
#   drop         -10.957
#   cricket      -10.957
#   congress     -9.011
#   thread       -10.264
#   baker        -9.165
#   martin       -8.392
#   pansies      -9.570
#   cereal       -9.570
#   nevertheless -7.293
#   uncle        -9.165
#   skinny       -10.957
#   students     -8.760
#   gracias      -10.957
#   washington   -8.012
#   advertising  -10.264
#   greg         -8.184
#   estimates    -10.957
#   command      -10.264
#   cathy        -10.264
#   mars         -10.957
#   tolley       -9.858
#   promptly     -9.858
#   mendoza      -10.957
#   snow         -9.858
#   eichmann     -10.957
#   consulting   -9.858
#   sec          -8.184
#   susie        -10.264
#   fashion      -9.858
#   salt         -9.858
#   division     -9.165
#   extend       -9.858
#   roosevelt    -10.264
#   krakow       -10.957
#   quickly      -10.264
#   repeated     -9.858
#   bryn         -10.957
#   much         -7.430
#   particularly -9.347
#   outlook      -10.957
#   charts       -10.957
#   children     -9.165
#   rice         -10.957
#   robby        -10.264
#   zion         -10.264
#   old          -8.318
#   orlick       -9.858
#   late         -9.858
#   danger       -10.957
#   forgive      -10.957
#   7            -8.124
#   labor        -9.165
#   gorton       -8.472
#   foster       -9.347
#   pumblechook  -10.264
#   wherefore    -10.264
#   unemployed   -10.957
#   look         -7.866
#   walter       -9.858
#   religion     -8.184
#   radio        -8.760
#   cady         -8.249
#   rhode        -9.347
#   tack         -10.957
#   wildlife     -10.957
#   mileage      -10.264
#   republicans  -10.957
#   michael      -10.957
#   tomorrow     -10.264
#   hong         -10.264
#   dewey        -10.264
#   true         -8.392
#   chris        -9.858
#   mama         -8.184
#   roberts      -9.347
#   me           -10.957
#   average      -10.264
#   morse        -9.347
#   ninety       -10.264
#   reliance     -10.957
#   sociological -10.957
#   mazeroski    -10.957
#   trooper      -10.957
#   commerce     -9.858
#   stereo       -9.570
#   surrounded   -10.264
#   hickory      -9.858
#   conclusions  -10.957
#   burial       -10.957
#   vicky        -10.957
#   nathanael    -10.957
#   halting      -10.957
#   near         -9.011
#   miami        -9.570
#   american     -8.472
#   systems      -10.264
#   paintings    -10.264
#   boxell       -10.264
#   strong       -9.165
#   lieutenant   -9.858
#   powerful     -10.957
#   roberta      -9.165
#   determine    -8.249
#   earthquakes  -10.264
#   edison       -10.957
#   photograph   -10.957
#   contrary     -9.165
#   returns      -9.858
#   byron        -9.570
#   deadlock     -10.957
#   analogously  -10.957
#   imagine      -9.165
#   cows         -9.858
#   c'm          -9.858
#   attorney     -9.858
#   cried        -9.570
#   kind         -9.858
#   elementary   -10.957
#   aroused      -10.957
#   volume       -8.559
#   drill        -8.760
#   lucretius    -10.957
#   dandy        -10.957
#   ahead        -9.858
#   8            -9.011
#   escalation   -10.264
#   ideas        -9.570
#   air          -9.858
#   lighted      -10.957
#   whatever     -7.866
#   romantic     -10.957
#   patrolman    -9.570
#   ensign       -10.264
#   history      -9.858
#   pending      -10.957
#   india        -10.957
#   frowning     -10.957
#   todman       -9.858
#   ordinary     -9.347
#   successive   -10.957
#   manchester   -10.264
#   having       -7.961
#   brooklyn     -9.570
#   leona        -10.957
#   katherine    -10.264
#   businessmen  -10.264
#   secretion    -10.957
#   unspeakable  -10.957
#   armed        -9.165
#   sba          -8.760
#   could        -7.912
#   six          -7.912
#   rhyme        -10.957
#   stevenson    -10.264
#   funds        -9.347
#   records      -9.858
#   tensile      -10.957
#   utopia       -10.957
#   estimated    -10.264
#   robert       -8.877
#   heads        -10.957
#   owen         -9.165
#   laura        -9.165
#   adjoining    -10.957
#   follow       -9.347
#   independence -10.957
#   technical    -9.858
#   majestic     -10.957
#   pilot        -10.264
#   leasing      -10.957
#   coach        -10.957
#   square       -10.264
#   hal          -8.877
#   trim         -9.347
#   fighting     -10.957
#   four         -7.821
#   allied       -9.570
#   tilghman     -9.165
#   women        -9.570
#   swears       -10.957
#   using        -8.472
#   long         -8.249
#   famed        -10.957
#   historically -9.347
#   clumps       -10.264
#   telefunken   -10.957
#   longwood     -10.957
#   strategic    -10.957
#   fierce       -10.957
#   twenty       -8.124
#   prof.        -10.957
#   inflammatory -10.957
#   closely      -9.858
#   depending    -10.957
#   sure         -9.165
#   nixon        -10.957
#   wisman       -10.264
#   hubie        -10.957
#   police       -9.011
#   exponents    -10.957
#   roger        -10.264
#   unwarranted  -10.957
#   david        -8.559
#   carefully    -10.264
#   continuous   -9.858
#   klauber      -10.957
#   special      -9.165
#   carried      -10.957
#   form         -10.264
#   ludie        -8.877
#   myra         -9.347
#   i.e.         -9.858
#   de           -9.570
#   survivors    -9.347
#   idje         -10.264
#   revulsion    -10.957
#   macklin      -9.858
#   increase     -10.957
#   hengesbach   -9.858
#   additional   -8.318
#   confabulation -10.957
#   skorich      -9.347
#   sports       -10.957
#   combine      -9.858
#   experiment   -9.570
#   bright       -10.264
#   getz         -10.957
#   believe      -10.957
#   resisting    -10.957
#   ;            -9.165
#   moscow       -9.347
#   4            -7.346
#   george       -8.124
#   castaneda    -10.957
#   man          -8.124
#   fine         -10.957
#   horse        -10.264
#   camping      -10.264
#   berto        -9.858
#   unlike       -8.760
#   central      -9.570
#   bowie        -10.957
#   curious      -10.957
#   writes       -9.347
#   sighing      -10.264
#   anta         -10.957
#   somewhere    -8.559
#   artistic     -10.957
#   reaction     -9.858
#   lemma        -9.570
#   p            -10.957
#   geographic   -10.957
#   merely       -10.264
#   soon         -7.866
#   funeral      -9.570
#   calcium      -9.858
#   guests       -9.347
#   anglo        -10.264
#   youngsters   -10.264
#   teaching     -9.347
#   presenting   -10.957
#   park         -10.957
#   mayer        -10.957
#   angelo       -10.957
#   aunt         -10.957
#   creighton    -10.957
#   clerfayt     -9.570
#   precise      -10.264
#   ducking      -10.264
#   encouraging  -10.264
#   ten          -8.318
#   cattle       -9.011
#   interest     -9.165
#   abel         -9.347
#   walker       -10.957
#   oils         -10.957
#   none         -8.184
#   bottoms      -10.957
#   bits         -10.957
#   processing   -9.858
#   weakness     -10.957
#   tailback     -10.957
#   rangoni      -9.858
#   purchase     -10.264
#   graft        -10.957
#   president    -8.249
#   baptists     -10.957
#   monel        -10.264
#   glowering    -10.957
#   approximately -9.165
#   idols        -10.957
#   nate         -10.264
#   hotel        -10.264
#   africans     -10.957
#   present      -9.165
#   lightweight  -10.957
#   inevitably   -9.858
#   gradually    -8.877
#   casey        -9.165
#   fudo         -10.957
#   chief        -8.877
#   moon         -10.957
#   inland       -10.957
#   vastly       -10.957
#   probable     -10.957
#   class        -9.858
#   quintus      -10.957
#   abstractions -10.957
#   read         -9.347
#   guar         -10.957
#   district     -10.957
#   realtors     -9.858
#   april        -9.858
#   handsome     -10.957
#   twice        -8.877
#   12           -9.570
#   makes        -9.347
#   eventually   -8.760
#   violent      -10.957
#   jay          -9.858
#   figure       -8.877
#   clearly      -8.760
#   rental       -10.957
#   seward       -10.957
#   saami        -10.264
#   leaving      -8.877
#   211          -10.957
#   costs        -9.347
#   recovering   -10.957
#   international -9.347
#   afraid       -10.957
#   spoilage     -10.957
#   proceeding   -9.858
#   following    -8.184
#   price        -9.858
#   mahzeer      -9.165
#   arnold       -9.011
#   russ         -9.165
#   authenticated -10.957
#   stronger     -10.957
#   wisely       -10.957
#   holidays     -10.264
#   jesus        -8.760
#   young        -8.877
#   acting       -9.858
#   supposing    -10.957
#   regulative   -10.957
#   ca           -8.654
#   existence    -10.957
#   reflex       -10.957
#   giselle      -10.957
#   carla        -10.957
#   pool         -10.957
#   viewed       -10.957
#   faced        -9.570
#   alloy        -10.957
#   hood         -10.264
#   directed     -10.264
#   committee    -10.957
#   occupational -10.957
#   good         -7.912
#   indicating   -10.957
#   impressive   -10.957
#   speaking     -8.472
#   furnishes    -10.957
#   cleaned      -10.957
#   imperfectly  -10.957
#   specimens    -10.264
#   brannon      -8.760
#   slightly     -10.957
#   expressed    -10.957
#   kneeling     -10.957
#   wait         -9.570
#   hartman      -10.264
#   eugenia      -9.858
#   hub          -9.011
#   responsibility -10.957
#   immediately  -9.165
#   flat         -10.957
#   subsequent   -10.264
#   arlene       -9.165
#   counsel      -9.858
#   chuck        -9.858
#   animals      -9.858
#   sizable      -10.957
#   music        -9.347
#   want         -10.264
#   inject       -10.957
#   jean         -9.165
#   toying       -10.957
#   u.           -10.264
#   numerical    -10.957
#   cappy        -9.570
#   preparation  -9.011
#   julian       -10.957
#   dartmouth    -9.347
#   current      -10.264
#   countered    -10.957
#   neuropathology -10.957
#   mollie       -10.264
#   shy          -10.264
#   fulton       -10.264
#   hunting      -10.957
#   multiple     -10.957
#   dolores      -9.570
#   del          -10.957
#   tappets      -10.957
#   payne        -9.570
#   add          -8.559
#   starlings    -10.957
#   easily       -10.957
#   hillsboro    -10.957
#   consitutional -10.957
#   molly        -10.957
#   c            -9.165
#   beebe        -10.264
#   occasionally -8.184
#   exceptions   -10.957
#   discussions  -10.957
#   napkin       -10.957
#   seated       -9.858
#   exhibited    -10.957
#   edward       -10.264
#   drain        -9.858
#   carmer       -10.264
#   bevo         -10.957
#   traitor      -10.957
#   traders      -10.957
#   mary         -8.184
#   per          -10.264
#   news         -9.570
#   onsets       -10.957
#   duren        -10.957
#   greatest     -10.264
#   everybody    -8.654
#   sometime     -10.264
#   sharing      -10.957
#   jackie       -10.957
#   based        -9.858
#   frankfurter  -10.957
#   346          -10.957
#   britain      -9.347
#   haney        -8.472
#   bring        -10.264
#   forgiveness  -10.264
#   amy          -9.858
#   big          -9.011
#   brown        -10.264
#   clasping     -10.957
#   incurably    -10.957
#   ventilation  -10.264
#   paula        -9.570
#   achilles     -10.957
#   dictionary   -10.264
#   wine         -9.347
#   substances   -9.165
#   hired        -10.957
#   gordin       -10.957
#   february     -10.957
#   resting      -10.957
#   explains     -10.957
#   best         -9.011
#   pond         -10.957
#   mulligan     -10.957
#   ann          -9.011
#   walitzee     -10.264
#   harris       -9.858
#   nice         -9.570
#   kayabashi    -10.957
#   economic     -9.347
#   root         -10.957
#   place        -7.699
#   middletown   -10.957
#   shocked      -10.264
#   fahey        -10.957
#   jess         -8.472
#   books        -10.264
#   stein        -9.858
#   parents      -8.877
#   considered   -10.957
#   information  -8.877
#   shell        -9.347
#   neglecting   -10.957
#   respondents  -9.347
#   walking      -9.570
#   arrange      -10.957
#   dunes        -10.957
#   purpose      -10.264
#   thanks       -9.011
#   tom          -8.654
#   o            -9.858
#   reply        -9.347
#   knows        -10.957
#   pa           -8.877
#   paradoxically -9.858
#   boating      -10.264
#   same         -9.347
#   rumor        -10.264
#   micelles     -10.957
#   ramey        -8.392
#   kings        -10.957
#   sweat        -9.858
#   francesca    -9.570
#   offer        -10.957
#   fixed        -9.347
#   johnson      -8.877
#   hatred       -10.957
#   selena       -10.264
#   industry     -9.165
#   net          -9.570
#   preoccupied  -10.957
#   rexroth      -9.570
#   proper       -9.858
#   disagreement -10.957
#   painters     -10.957
#   haydn        -10.264
#   15           -10.264
#   mij          -10.957
#   adams        -9.570
#   operations   -10.264
#   wade         -10.957
#   funny        -10.957
#   captain      -9.011
#   mantle       -8.392
#   derails      -10.957
#   ideally      -9.347
#   martha       -9.570
#   ultimately   -9.570
#   official     -9.858
#   speak        -10.264
#   hard         -10.264
#   shotgun      -10.957
#   recognizing  -9.570
#   julie        -10.264
#   nigger       -10.957
#   surely       -8.877
#   studies      -9.570
#   unstained    -10.957
#   supporting   -10.264
#   foliage      -9.858
#   real         -10.264
#   birmingham   -10.957
#   employee     -10.957
#   seen         -9.858
#   anyway       -8.877
#   alcohol      -10.957
#   schweitzer   -10.957
#   lots         -9.858
#   leadership   -9.858
#   holmes       -9.347
#   conceivably  -10.957
#   eleazar      -10.264
#   draw         -9.570
#   opportunities -10.957
#   ralph        -10.264
#   bless        -10.957
#   company      -10.957
#   unquestionably -10.264
#   solid        -9.165
#   norton       -10.264
#   growing      -10.264
#   seeming      -10.264
#   fear         -9.570
#   possible     -10.957
#   orders       -9.858
#   idea         -10.957
#   production   -9.011
#   legs         -10.957
#   capital      -10.264
#   note         -8.012
#   lay          -10.957
#   hillman      -10.264
#   turbulent    -10.957
#   silence      -9.858
#   juanita      -9.858
#   bingles      -10.957
#   hanford      -9.858
#   markets      -10.957
#   facing       -10.264
#   departing    -10.957
#   plus         -10.264
#   soak         -10.957
#   tone         -9.570
#   taken        -9.858
#   russian      -10.264
#   sarah        -9.165
#   wheaton      -10.957
#   electrical   -10.264
#   free         -10.957
#   palmer       -9.011
#   speakers     -10.264
#   caring       -10.957
#   ring         -10.957
#   clay         -10.957
#   doubt        -10.957
#   progress     -9.347
#   rectangular  -10.957
#   frostbite    -10.957
#   peak         -10.957
#   howard       -9.347
#   feeds        -10.264
#   tribal       -10.957
#   female       -10.957
#   huff         -9.570
#   leading      -10.264
#   missail      -10.957
#   consumer     -10.957
#   approaching  -10.264
#   unanimously  -10.957
#   made         -10.264
#   buying       -10.957
#   princes      -10.957
#   burly        -10.957
#   oyster       -10.957
#   waddell      -8.654
#   marine       -10.957
#   field        -9.011
#   visualize    -10.957
#   words        -10.264
#   looking      -8.877
#   nakamura     -10.264
#   aircraft     -10.957
#   proprietorships -9.858
#   preliminary  -9.858
#   age          -10.264
#   publishers   -10.957
#   confronted   -10.264
#   channel      -10.264
#   w.           -9.347
#   third        -8.760
#   somewhat     -9.347
#   which        -8.184
#   declinations -10.957
#   propriety    -10.957
#   payments     -10.264
#   aristotle    -10.264
#   intelligence -9.858
#   nitrogen     -10.264
#   mass         -10.264
#   pels         -10.264
#   averages     -10.957
#   really       -9.570
#   disturbing   -10.957
#   schwarzkopf  -10.957
#   continuing   -9.570
#   liz          -10.957
#   voegelin     -10.957
#   technique    -10.957
#   facilitatory -10.957
#   probably     -7.866
#   unmarried    -10.957
#   money        -9.347
#   sen.         -9.570
#   additionally -9.858
#   sanitation   -10.957
#   nursing      -10.957
#   hendricks    -10.264
#   babe         -10.264
#   conversely   -9.347
#   compulsory   -10.957
#   seidel       -10.957
#   driving      -10.957
#   assistant    -9.570
#   outline      -10.957
#   seasonal     -10.957
#   pakistan     -10.957
#   mouse        -10.957
#   fig          -10.264
#   texts        -10.957
#   deity        -10.957
#   downers      -10.957
#   slate        -10.957
#   changing     -9.858
#   obligingly   -10.957
#   coaching     -10.264
#   personal     -9.858
#   jack         -8.654
#   justices     -10.264
#   fresh        -9.570
#   vince        -9.011
#   supplemental -10.957
#   amid         -10.264
#   papa         -9.347
#   psychical    -10.957
#   beadle       -10.957
#   hanging      -9.858
#   exemption    -10.957
#   physiologist -10.957
#   significant  -10.957
#   emory        -10.264
#   mickey       -8.559
#   nonresident  -10.264
#   thought      -9.858
#   magwitch     -10.264
#   union        -9.858
#   loyal        -10.957
#   beverages    -10.957
#   reading      -10.264
#   mud          -10.957
#   missionary   -10.264
#   cottonmouth  -10.957
#   line         -10.264
#   erikson      -9.858
#   aside        -8.654
#   mark         -8.877
#   ceramic      -10.957
#   reception    -10.957
#   considering  -8.877
#   desperately  -10.957
#   vesole       -10.264
#   fifteen      -9.347
#   pausing      -9.858
#   became       -10.957
#   northerners  -10.264
#   states       -10.264
#   winsett      -10.957
#   holden       -9.858
#   fitting      -10.957
#   2.6          -10.957
#   dave         -9.011
#   colorado     -10.264
#   dec.         -10.957
#   backstitch   -10.264
#   overwhelmed  -10.957
#   liston       -10.957
#   lumpe        -10.264
#   refill       -10.264
#   jubal        -9.165
#   oxygen       -10.957
#   softer       -10.957
#   sandwich     -10.957
#   moritz       -9.165
#   sufficiently -10.957
#   newspapers   -10.957
#   sir          -8.318
#   step         -10.957
#   christianity -10.957
#   eating       -10.264
#   sandburg     -10.957
#   mail         -10.264
#   hans         -8.559
#   gratified    -10.957
#   proposals    -10.264
#   sixty        -9.165
#   platform     -10.264
#   honest       -10.264
#   corollary    -10.264
#   future       -9.570
#   agriculture  -10.264
#   thinking     -9.347
#   venn         -10.264
#   ran          -10.264
#   criticality  -9.347
#   publisher    -10.264
#   ground       -9.858
#   andrei       -8.559
#   devoted      -10.957
#   armbro       -10.957
#   beef         -10.264
#   ernest       -10.264
#   conchita     -9.858
#   findings     -10.957
#   badly        -10.957
#   f.           -9.858
#   nostalgic    -10.957
#   pirate       -10.957
#   pa'd         -10.957
#   b            -9.011
#   rawlins      -10.957
#   bathing      -10.957
#   okay         -10.264
#   weld         -10.264
#   carl         -8.654
#   grabski      -9.347
#   seven        -8.654
#   conceding    -10.957
#   suspicion    -10.264
#   greer        -10.957
#   alley        -10.957
#   paredon      -10.957
#   into         -9.165
#   dill         -9.858
#   length       -10.957
#   has          -9.011
#   properties   -9.347
#   killpath     -9.011
#   subjects     -10.957
#   prevents     -10.957
#   insofar      -10.264
#   dallas       -9.165
#   whole        -9.858
#   elena        -10.957
#   authorities  -9.858
#   combellack   -10.957
#   scotty       -8.066
#   1960         -10.264
#   organization -9.347
#   cecil        -10.957
#   historians   -9.858
#   scores       -10.264
#   side         -10.957
#   ezra         -10.957
#   introduction -9.011
#   sales        -9.011
#   django       -10.264
#   lady         -10.264
#   extensions   -9.858
#   microorganisms -10.957
#   durkheim     -10.957
#   fury         -9.347
#   somehow      -8.318
#   expands      -10.957
#   stars        -10.264
#   divergent    -10.957
#   whom         -9.858
#   claire       -10.264
#   headquarters -9.570
#   visitors     -10.264
#   harry        -9.347
#   wexler       -9.858
#   heating      -10.957
#   dollar       -10.957
#   written      -10.957
#   potemkin     -9.858
#   tension      -9.858
#   toward       -9.165
#   services     -10.264
#   strenuous    -10.957
#   carbondale   -10.957
#   gray         -9.858
#   monte        -10.957
#   tall         -10.264
#   analysis     -9.347
#   mousie       -10.264
#   grazie       -10.264
#   custom       -10.957
#   gauer        -10.957
#   americans    -9.858
#   bobbie       -9.347
#   barbara      -9.570
#   chairman     -9.858
#   vapor        -10.957
#   feebly       -10.957
#   move         -9.858
#   joviality    -10.957
#   inside       -8.559
#   earlier      -9.858
#   candy        -10.957
#   hegel        -10.957
#   concern      -10.957
#   d.           -10.957
#   anything     -8.877
#   satisfied    -10.957
#   brooks       -9.570
#   advisors     -10.957
#   treasonable  -10.957
#   ever         -8.877
#   seventeen    -10.264
#   east         -9.165
#   escape       -10.264
#   linked       -10.957
#   lizzie       -10.264
#   sweeping     -10.957
#   kluckhohn    -10.957
#   traffic      -9.165
#   hypothesizing -10.957
#   protection   -9.570
#   voting       -10.264
#   pitch        -10.264
#   christ       -9.570
#   lithe        -10.957
#   alexander    -8.760
#   newbiggin    -10.957
#   literature   -10.957
#   relieved     -10.957
#   eyes         -9.858
#   lighting     -9.570
#   judge        -9.165
#   drums        -10.957
#   magnificent  -10.957
#   drifts       -10.264
#   signora      -10.957
#   fuzzy        -10.957
#   stanley      -9.347
#   wetting      -10.957
#   repeat       -10.957
#   drying       -10.264
#   booth        -10.957
#   highly       -10.957
#   professional -10.957
#   pupil        -10.957
#   donovan      -10.957
#   &            -10.264
#   felix        -9.165
#   displaying   -10.957
#   centering    -10.957
#   conceived    -10.957
#   syllabification -10.957
#   chauncey     -10.957
#   bridges      -10.264
#   discoveries  -10.957
#   ruling       -10.957
#   coffee       -9.858
#   end          -9.570
#   excess       -10.957
#   vocational   -9.858
#   samos        -10.957
#   brenner      -9.858
#   kieffer      -10.957
#   millie       -10.264
#   statues      -10.957
#   henri        -10.957
#   unsuccessful -10.957
#   reasons      -10.957
#   seldom       -10.957
#   stop         -9.858
#   dennis       -10.957
#   illustrations -10.264
#   tracing      -10.957
#   think        -9.858
#   biological   -9.347
#   underneath   -9.570
#   occasional   -9.347
#   belt         -10.957
#   mando        -10.957
#   cherkasov    -10.957
#   carpenters   -10.957
#   blasphemous  -10.957
#   given        -9.347
#   respecting   -10.957
#   younger      -10.264
#   apples       -10.957
#   gavin        -8.760
#   meantime     -10.264
#   powers       -9.858
#   normally     -10.264
#   plans        -9.570
#   principal    -9.858
#   spike        -10.957
#   11           -10.264
#   lauren       -9.347
#   refunds      -10.264
#   crystallographic -10.264
#   newcomers    -9.858
#   neighbor     -10.957
#   typically    -9.858
#   georgia      -9.347
#   create       -10.957
#   declaration  -10.957
#   art          -9.858
#   assumption   -9.858
#   finnegan     -10.957
#   prokofieff   -9.165
#   measured     -10.957
#   literal      -10.957
#   attacks      -10.264
#   service      -10.264
#   judgments    -10.957
#   spencer      -9.570
#   flanked      -10.957
#   ambassador   -9.858
#   along        -8.472
#   origin       -10.264
#   modifications -10.957
#   parker       -8.559
#   singing      -10.264
#   accepted     -10.957
#   nearness     -10.264
#   demagogues   -10.957
#   laguardia    -10.957
#   pelham       -10.264
#   kirby        -10.957
#   broil        -10.957
#   emotionally  -10.264
#   test         -9.347
#   fat          -9.858
#   secrecy      -10.957
#   washed       -10.957
#   language     -10.957
#   st.          -8.066
#   right        -9.011
#   angelina     -10.264
#   graduates    -10.957
#   used         -10.957
#   brakes       -10.264
#   tsunami      -10.264
#   dimly        -10.264
#   gather       -10.957
#   briefly      -10.957
#   touring      -10.957
#   boniface     -10.264
#   lolotte      -10.264
#   severe       -10.264
#   keeeerist    -10.957
#   rooney       -10.957
#   point        -10.957
#   delphine     -9.570
#   shirl        -10.957
#   definition   -9.858
#   desegregation -9.347
#   negligence   -10.957
#   cutting      -9.858
#   remarks      -9.347
#   prevention   -10.264
#   turmoil      -10.957
#   smith        -10.264
#   greek        -9.347
#   artie        -10.957
#   selkirk      -10.957
#   lord         -9.011
#   stevens      -10.264
#   loveless     -10.957
#   chairs       -10.957
#   carcinoma    -10.957
#   rep.         -9.011
#   molding      -10.957
#   accept       -10.957
#   billy        -9.165
#   theologians  -10.957
#   summary      -10.264
#   coming       -9.858
#   planes       -10.264
#   concessionaires -10.957
#   deep         -10.957
#   metrically   -10.957
#   mickie       -9.858
#   readings     -10.957
#   bridget      -9.858
#   quint        -9.347
#   writing      -9.858
#   handing      -10.957
#   wards        -10.957
#   lucius       -10.957
#   bergson      -10.957
#   letters      -9.858
#   auto         -9.858
#   electron     -10.957
#   o.           -10.957
#   0            -10.957
#   handsomest   -10.957
#   lumber       -10.957
#   clock        -10.957
#   education    -9.858
#   eighteenth   -10.957
#   county       -9.570
#   wolpe        -10.957
#   maggie       -9.011
#   van          -10.264
#   explanation  -10.957
#   half         -8.877
#   knowing      -9.858
#   milton       -9.347
#   riding       -10.957
#   metaphysics  -10.957
#   bostitch     -10.957
#   ripe         -10.264
#   everywhere   -9.165
#   katya        -10.264
#   contraction  -10.957
#   join         -9.858
#   founded      -10.264
#   practically  -9.165
#   hundreds     -9.858
#   lucien       -10.957
#   turn         -8.877
#   cleaning     -10.957
#   dean         -9.165
#   designing    -10.957
#   adios        -10.957
#   single       -9.858
#   fairmount    -10.957
#   kiwanis      -10.957
#   beckworth    -10.264
#   ice          -10.264
#   capitalism   -10.957
#   spokesmen    -10.957
#   alfred       -8.472
#   representing -10.264
#   analyses     -10.264
#   utilize      -10.957
#   procreation  -10.957
#   changes      -9.858
#   scenic       -10.957
#   thereafter   -9.570
#   bevel        -10.264
#   physically   -10.264
#   southern     -9.165
#   negro        -9.570
#   biggest      -10.957
#   relative     -10.264
#   gynecologists -10.957
#   may          -9.165
#   pennsylvania -9.858
#   dumont       -10.957
#   grudges      -10.957
#   wright       -9.858
#   chiefly      -10.957
#   lightning    -10.264
#   deliberately -10.264
#   b'dikkat     -9.858
#   paced        -10.957
#   flocks       -10.957
#   andy         -8.124
#   presses      -10.957
#   australia    -10.957
#   motorists    -10.957
#   necessary    -10.957
#   nourishing   -10.957
#   carrie       -10.957
#   russia       -9.165
#   nightclubs   -10.957
#   matters      -10.957
#   hammarskjold -9.858
#   floating     -10.957
#   sample       -9.858
#   pohl         -9.570
#   months       -10.957
#   meaningful   -10.957
#   seemingly    -10.264
#   leslie       -10.957
#   provide      -10.264
#   final        -9.858
#   order        -10.957
#   doaty        -10.957
#   discovery    -10.264
#   due          -10.264
#   faulkner     -8.877
#   errors       -10.264
#   united       -9.570
#   nineteenth   -10.957
#   agamemnon    -10.957
#   claude       -10.957
#   equally      -9.858
#   dutton       -10.957
#   means        -9.165
#   health       -10.264
#   iosola       -10.957
#   seizing      -10.957
#   necessity    -10.957
#   presumably   -9.165
#   nature       -10.264
#   grandparents -10.264
#   barton       -8.392
#   soil         -10.264
#   explicit     -10.957
#   mellow       -10.957
#   andrea       -10.957
#   soothing     -10.957
#   color        -10.264
#   yff          -10.957
#   altogether   -9.570
#   rents        -10.957
#   reagents     -10.957
#   partly       -9.858
#   breath       -10.957
#   providence   -10.264
#   willis       -9.858
#   distillers   -10.957
#   hino         -9.858
#   starr        -10.957
#   steele       -9.011
#   house        -10.264
#   run          -10.264
#   douglass     -9.570
#   ironically   -9.858
#   d            -9.165
#   tactics      -10.957
#   hours        -10.957
#   democrat     -10.957
#   blend        -10.957
#   rosburg      -10.957
#   macneff      -9.858
#   experimentally -10.957
#   miraculously -9.858
#   jim          -8.760
#   nonspecific  -10.957
#   worse        -10.264
#   prompted     -10.957
#   tonal        -10.264
#   plato        -9.347
#   cap          -9.570
#   weight       -10.957
#   opinion      -10.957
#   inventories  -10.957
#   board        -9.858
#   havana       -10.264
#   clothes      -10.957
#   promoters    -10.264
#   capt         -10.264
#   meredith     -9.570
#   brains       -10.957
#   black        -9.347
#   heidenstam   -9.570
#   sugar        -10.264
#   exploratory  -10.957
#   sedgwick     -10.957
#   folklore     -9.858
#   demanded     -10.264
#   crooked      -10.957
#   civilization -10.264
#   saturday     -10.957
#   blanche      -9.858
#   beginning    -9.347
#   kidnaper     -10.957
#   saul         -10.264
#   elections    -10.957
#   gulf         -9.858
#   allow        -10.264
#   2.1.6        -10.957
#   ortega       -10.957
#   bullets      -10.264
#   procedure    -10.957
#   selections   -10.957
#   placement    -10.264
#   caldwell     -10.957
#   glimco       -10.957
#   roast        -10.957
# ...
#   writers      -8.833
#   parallel     -8.833
#   bourbon      -8.833
#   return       -7.734
#   cores        -8.833
#   continuities -8.833
#   incomplete   -8.833
#   soybean      -8.833
#   threadbare   -8.833
#   arrest       -8.833
#   knife        -8.833
#   predomination -8.833
#   round        -8.140
#   search       -8.140
#   playing      -8.833
#   dirty        -8.833
#   animosity    -8.833
#   unabashed    -8.833
#   living       -8.140
#   comprehensive -8.833
#   glazer       -8.833
#   apex         -8.833
#   eyeteeth     -8.833
#   classical    -8.833
#   yugoslav     -8.833
#   22           -8.833
#   worst        -8.140
#   wooden       -8.833
#   inhibition   -8.833
#   totals       -8.833
#   ex           -8.833
#   chickasaws   -8.140
#   handsome     -8.833
#   steady       -8.140
#   positive     -8.140
#   radioactivity -8.833
#   contention   -8.833
#   managers     -8.833
#   potters      -8.140
#   altercation  -8.833
#   massed       -8.833
#   startling    -8.833
#   shadows      -8.140
#   ifni         -8.833
#   epiphany     -8.833
#   lordly       -8.833
#   will         -8.833
#   989          -8.833
#   p.d.i.       -8.833
#   receiver     -8.833
#   warped       -8.833
#   magistrate   -8.833
#   commissioners -8.833
#   republicans  -8.140
#   belligerent  -8.833
#   bathyrans    -8.140
#   engineering  -8.140
#   subsequent   -8.833
#   spray        -8.833
#   rationale    -8.833
#   newlyweds    -8.833
#   interviews   -8.833
#   item         -8.833
#   contributions -8.833
#   1962         -8.833
#   contributors -8.833
#   vegetables   -8.833
#   explanation  -8.833
#   clearly      -8.833
#   sommelier    -8.833
#   grounds      -8.833
#   type         -8.140
#   nashville    -8.833
#   pro          -8.833
#   egyptians    -8.833
#   curtains     -8.833
#   def          -8.833
#   ensemble     -8.833
#   banks        -8.833
#   shooting     -8.833
#   test         -8.833
#   fashion      -8.833
#   plank        -8.833
#   sculptor     -8.140
#   sensation    -8.833
#   efforts      -8.140
#   acropolis    -8.140
#   symbol       -7.447
#   raf          -8.833
#   networks     -8.833
#   protestant   -8.833
#   honor        -8.833
#   assessors    -8.833
#   mecholyl     -8.833
#   landscape    -8.140
#   oracle       -8.833
#   defendant    -8.833
#   movie        -8.833
#   statistics   -8.833
#   gyro         -8.833
#   operator     -8.140
#   bitterness   -8.833
#   tweed        -8.833
#   fences       -8.140
#   artkino      -8.833
#   grafin       -8.833
#   fins         -8.833
#   aircraft     -8.833
#   suggested    -8.833
#   discovery    -7.734
#   calf         -8.833
#   highest      -7.734
#   paper        -8.140
#   duration     -8.140
#   race         -8.833
#   alabaster    -8.833
#   request      -8.833
#   skeletal     -8.833
#   interchange  -8.833
#   chromatography -8.833
#   debris       -8.833
#   realm        -8.833
#   disclosure   -8.833
#   cooking      -8.140
#   promotion    -8.833
#   rules        -8.833
#   wildlife     -8.833
#   penalty      -8.833
#   ch'an        -8.833
#   success      -8.833
#   battens      -8.140
#   corpse       -8.833
#   dosages      -8.833
#   chines       -8.833
#   congregation -8.140
#   pulpit       -8.833
#   romantics    -8.833
#   stanford     -8.833
#   procedure    -8.833
#   magazine     -8.833
#   opposition   -8.833
#   riverside    -8.833
#   outer        -8.833
#   headline     -8.833
#   slight       -8.833
#   robbers      -8.833
#   cynicism     -8.833
#   ratio        -8.140
#   required     -8.833
#   33           -8.833
#   frequencies  -8.833
#   bomb         -8.140
#   chase        -8.833
#   credo        -8.833
#   regiment     -8.833
#   fertility    -8.833
#   u.n.         -8.140
#   rockies      -8.833
#   trompe       -8.833
#   deputy       -8.833
#   saline       -8.140
#   ceaseless    -8.833
#   prisoners    -8.140
#   antecedents  -8.833
#   puzzled      -8.833
#   parents      -8.833
#   presto       -8.833
#   detergent    -8.833
#   cumulative   -8.833
#   life         -8.833
#   plants       -8.833
#   targo        -8.833
#   females      -8.833
#   strategic    -8.833
#   twins        -8.833
#   wizard       -8.833
#   tortured     -8.833
#   difficulty   -8.140
#   depth        -8.833
#   fluidity     -8.833
#   professed    -8.833
#   pets         -8.833
#   deadliness   -8.833
#   consequences -8.833
#   storms       -8.833
#   courthouse   -8.833
#   gains        -8.833
#   bombproof    -8.833
#   basis        -8.833
#   socialism    -8.833
#   deacon       -8.140
#   cocktail     -8.833
#   production   -8.833
#   insoluble    -8.140
#   abbot        -8.833
#   hell         -8.833
#   departure    -8.833
#   full         -8.833
#   y.m.c.a.     -8.833
#   o            -8.833
#   jug          -8.833
#   startlingly  -8.833
#   fault        -8.833
#   exoneration  -8.833
#   bottle       -8.833
#   widely       -8.833
#   beaming      -8.833
#   preparations -8.833
#   measures     -8.833
#   covers       -8.833
#   300th        -8.833
#   growth       -8.140
#   charles      -8.140
#   professor    -8.833
#   property     -8.140
#   tallyho      -8.833
#   pointed      -8.833
#   tall         -8.140
#   scant        -8.833
#   well         -8.833
#   husbands     -8.833
#   burkes       -8.833
#   42           -8.833
#   percentage   -8.140
#   distant      -8.833
#   continuity   -8.833
#   forthcoming  -8.833
#   desire       -7.734
#   agencies     -8.833
#   complex      -8.833
#   expression   -8.140
#   misery       -8.833
#   bartender    -7.734
#   nonreactors  -8.833
#   speed        -8.833
#   careless     -8.833
#   legislative  -8.833
#   federals     -8.833
#   statutes     -8.833
#   rf           -8.833
#   herd         -8.833
#   predictability -8.833
#   times        -8.833
#   chevaux      -8.833
#   poetics      -8.833
#   proclamation -8.833
#   novelist     -8.833
#   surveyor     -8.833
#   honorable    -8.833
#   unrelieved   -8.833
#   library      -8.833
#   taxpayer     -8.833
#   augusta      -8.833
#   historical   -8.833
#   atom         -8.833
#   contestants  -8.833
#   george       -8.833
#   headsman     -8.833
#   hope         -8.833
#   royalty      -8.833
#   mathematical -8.833
#   skopas       -8.833
#   army         -8.140
#   welfare      -8.833
#   worthy       -8.833
#   myth         -8.833
#   imposition   -8.833
#   leveling     -8.833
#   dallas       -8.833
#   force        -7.734
#   deae         -8.833
#   trick        -8.833
#   biography    -8.833
#   alternative  -8.833
#   dupont       -8.833
#   micrometer   -8.833
#   actor        -8.833
#   plight       -8.833
#   collective   -8.833
#   fisherman    -8.833
#   periods      -8.833
#   marriage     -8.140
#   statutory    -8.833
#   taunt        -8.833
#   soccer       -8.833
#   scientific   -8.833
#   cleansing    -8.833
#   princess     -8.833
#   cylindrical  -8.833
#   admassy      -8.833
#   fragrance    -8.833
#   aimless      -8.833
#   boats        -8.833
#   length       -8.833
#   dolley       -8.833
#   resignation  -8.833
#   reference    -8.833
#   nest         -8.833
#   crystallographic -8.833
#   vocational   -8.833
#   republican   -8.833
#   series       -8.833
#   hostler      -8.833
#   identification -8.833
#   attendant    -8.140
#   rather       -8.833
#   staminate    -8.833
#   thirty       -8.833
#   intermediates -8.833
#   girders      -8.833
#   pipes        -8.833
#   dryer        -8.833
#   highway      -8.140
#   blair        -8.833
#   ramirez      -8.833
#   mapping      -8.833
#   essence      -8.833
#   dumbbell     -8.833
#   abernathys   -8.833
#   ireland      -8.833
#   questions    -8.833
#   splashes     -8.833
#   pulsing      -8.833
#   senses       -8.833
#   episcopal    -8.833
#   creator      -8.140
#   selkirk      -8.833
#   rating       -8.833
#   dreadnought  -8.833
#   u.s.s.r.     -8.833
#   shades       -8.833
#   beneficiaries -8.833
#   loss         -8.833
#   chenoweth    -8.833
#   attack       -8.833
#   avocado      -8.833
#   italians     -8.833
#   usefulness   -8.833
#   distinction  -8.833
#   businessman  -8.833
#   uptown       -8.833
#   fifteenth    -8.833
#   batteries    -8.833
#   peter        -8.833
#   transportation -8.833
#   unhealthy    -8.833
#   academic     -8.833
#   part         -8.140
#   miserable    -8.833
#   wording      -8.833
#   sine         -8.833
#   warwick      -8.833
#   defeat       -8.833
#   opposing     -8.833
#   inventory    -8.140
#   recommended  -8.833
#   associations -8.833
#   secret       -8.833
#   attackers    -8.833
#   points       -8.833
#   raw          -8.833
#   aerator      -8.833
#   difficulties -8.833
#   assumptions  -8.833
#   rooseveltian -8.833
#   superb       -8.833
#   heritage     -8.833
#   oxen         -8.833
#   kidneys      -8.833
#   onset        -8.833
#   fans         -8.833
#   behavior     -8.833
#   obscurity    -8.833
#   eventual     -8.833
#   bone         -8.833
#   supplier     -8.833
#   clients      -8.833
#   breakthrough -8.833
#   view         -8.833
#   legion       -8.833
#   effective    -8.833
#   rowdy        -8.833
#   tic          -8.833
#   emergence    -8.833
#   treasury     -8.833
#   swirling     -8.833
#   projection   -8.833
#   floc         -8.833
#   expenses     -8.833
#   160          -8.833
#   doppler      -8.833
#   cat          -8.833
#   strategy     -8.833
#   logical      -8.833
#   housekeeping -8.833
#   amazing      -8.833
#   meaningful   -8.833
#   stethoscope  -8.833
#   burial       -8.833
#   skirmishing  -8.833
#   connally     -8.833
#   butlers      -8.833
#   experts      -8.833
#   lilacs       -8.833
#   kremlin      -8.833
#   achievements -8.833
#   conversion   -8.140
#   fist         -8.833
#   malignancy   -8.833
#   operand      -8.833
#   searching    -8.833
#   turn         -8.833
#   preliminaries -8.833
#   foaming      -8.833
#   past         -8.833
#   leader       -8.833
#   fin          -8.833
#   suite        -8.833
#   postmaster   -8.833
#   norths       -8.833
#   shift        -8.833
#   7:45         -8.833
#   coronary     -8.833
#   landlord     -8.833
#   instrumental -8.833
#   almost       -8.833
#   something    -8.833
#   heavens      -8.140
#   biblical     -8.833
#   voltage      -8.833
#   slave        -8.833
#   hoaxes       -8.833
#   populations  -8.833
#   rides        -8.833
#   bringing     -8.833
#   collaboration -8.833
#   plus         -8.833
#   making       -8.833
#   peddler      -8.833
#   minuteman    -8.833
#   sticks       -8.833
#   clinico      -8.833
#   painting     -8.833
#   scientist    -8.833
#   consciousness -8.833
#   weeks        -8.833
#   motifs       -8.833
#   embarrassment -8.833
#   independence -8.833
#   scholarship  -8.833
#   savings      -8.833
#   fumes        -8.833
#   glisten      -8.833
#   amateur      -8.833
#   polyester    -8.833
#   glow         -8.833
#   apartment    -8.833
#   replacement  -8.833
#   rows         -8.833
#   fraction     -8.833
#   legend       -8.833
#   drizzle      -8.833
#   accelerometers -8.833
#   sweater      -8.833
#   terminal     -8.833
#   really       -8.833
#   uses         -8.140
#   variation    -8.833
#   whistle      -8.833
#   stallion     -8.833
#   ,            -8.833
#   rock         -8.833
#   laces        -8.833
#   criterion    -8.833
#   soap         -8.833
#   vagabonds    -8.833
#   prospects    -8.833
#   maguire      -8.833
#   gallant      -8.140
#   preservation -8.833
#   multiple     -8.833
#   rider        -8.833
#   trade        -8.140
#   pockets      -8.833
#   cross        -8.833
#   remote       -8.833
#   suez         -8.833
#   highroad     -8.833
#   deodorant    -8.833
#   subjects     -8.140
#   tie          -8.833
#   accumulated  -8.833
#   aluminum     -8.833
#   phony        -8.833
#   rehearsal    -8.833
#   scheme       -8.833
#   leopard      -8.833
#   utilities    -8.833
#   when         -8.833
#   taylor       -8.833
#   participants -8.833
#   happy        -8.833
#   mural        -8.833
#   dipylon      -8.833
#   halls        -8.833
#   wax          -8.833
#   hoofmarks    -8.833
#   prevalent    -8.833
#   purely       -8.833
#   agreeable    -8.833
#   drive        -8.833
#   motivations  -8.833
#   drums        -8.833
#   groth        -8.833
#   keystone     -8.833
#   horrifying   -8.833
#   iron         -8.833
#   harbor       -8.833
#   soviets      -8.833
#   hartsfield   -8.833
#   louvers      -8.833
#   sizes        -8.833
#   inadequacy   -8.833
#   ages         -8.833
#   handwriting  -8.833
#   relic        -8.833
#   gunfire      -8.833
#   cen          -8.833
#   chimney      -8.833
#   jungle       -8.833
#   fighting     -8.833
#   broncs       -8.833
#   lenin        -8.833
#   accomplishment -8.833
#   chinning     -8.833
#   patrolman    -8.833
#   discoid      -8.833
#   flite        -8.833
#   finding      -8.833
#   escheat      -8.833
#   wrinkled     -8.833
#   tensions     -8.833
#   bars         -8.833
#   eleanor      -8.833
#   viscous      -8.833
#   presentation -8.833
#   gunman       -8.833
#   blade        -8.833
#   denver       -8.833
#   father       -8.140
#   warning      -8.833
#   hawaiian     -8.833
#   downtown     -8.833
#   successful   -8.833
#   diffusion    -8.833
#   youngsters   -8.140
#   irish        -8.833
#   human        -8.140
#   countryside  -8.833
#   cooch        -8.833
#   moss         -8.833
#   farmers      -8.833
#   professional -8.833
#   connective   -8.833
#   un           -8.833
#   myocardium   -8.833
#   mahayana     -8.833
#   youngster    -8.833
#   radical      -8.833
#   jig          -8.833
#   bobbing      -8.833
#   cleaning     -8.833
#   omelet       -8.833
#   10.3         -8.833
#   sheets       -8.833
#   knifelike    -8.833
#   concertos    -8.833
#   spectrometer -8.833
#   lesson       -8.833
#   lives        -8.833
#   oxidation    -8.833
#   disappearance -8.833
#   pagodas      -8.833
#   blacked      -8.833
#   detectives   -8.833
#   monthly      -8.833
#   motorist     -8.833
#   ocean        -8.833
#   lavish       -8.833
#   gala         -8.833
#   lalauries    -8.833
#   corridor     -8.833
#   cloudburst   -8.833
#   portwatchers -8.833
#   hour         -8.833
#   bulletin     -8.833
#   twirled      -8.833
#   countin      -8.833
#   kernels      -8.833
#   finished     -8.833
#   animals      -8.833
#   bronchus     -8.833
#   progressive  -8.833
#   athletic     -8.833
#   preconditions -8.833
#   text         -8.833
#   horseman     -8.833
#   chicago      -8.140
#   tale         -8.833
#   release      -8.833
#   joseph       -8.833
#   function     -8.833
#   brother      -8.833
#   pond         -8.833
#   rusk         -8.833
#   widespread   -8.833
#   autofluorescence -8.833
#   tory         -8.833
#   applicant    -8.833
#   portland     -8.833
#   20           -8.833
#   works        -8.833
#   areas        -8.833
#   bellboy      -8.833
#   viewers      -8.833
#   pilots       -8.833
#   drexel       -8.833
#   spokesman    -8.833
#   events       -8.833
#   weekly       -8.833
#   stock        -8.833
#   twelfth      -8.833
#   gadget       -8.833
#   fast         -8.833
#   ecumenical   -8.833
#   lioness      -8.833
#   cavernous    -8.833
#   ''           -8.833
#   bassis       -8.833
#   wallpaper    -8.833
#   fabric       -8.833
#   calmness     -8.833
#   skin         -8.833
#   age          -8.833
#   voices       -8.833
#   ten          -8.833
#   velvet       -8.833
#   jacket       -8.833
#   get          -8.833
#   internationally -8.833
#   blonde       -8.833
#   limitations  -8.833
#   ceramic      -8.833
#   eichmann     -8.833
#   53           -8.833
#   qualifications -8.833
#   returns      -8.833
#   supermatic   -8.833
#   feet         -8.833
#   schism       -8.833
#   sensing      -8.833
#   consequence  -8.833
#   magic        -8.833
#   trends       -8.833
#   deductions   -8.833
#   construction -8.833
#   80           -8.833
#   cunard       -8.833
#   states       -8.833
#   dependence   -8.833
#   mercers      -8.833
#   promise      -8.833
#   brannon      -8.833
#   joints       -8.833
#   jobs         -8.833
#   storyline    -8.833
#   redcoats     -8.833
#   males        -8.833
#   chair        -8.833
#   missionary   -8.833
#   unstable     -8.833
#   canons       -8.833
#   interviewers -8.833
#   functional   -8.833
#   reception    -8.833
#   schuman      -8.833
#   zeitgeist    -8.833
#   gals         -8.833
#   self         -8.833
#   crux         -8.833
#   doctrine     -8.833
#   clause       -8.833
#   wholesome    -8.833
#   deposit      -8.833
#   death's      -8.833
#   breeze       -8.833
#   stink        -8.833
#   hired        -8.833
#   starbird     -8.833
#   charged      -8.833
#   ideals       -8.833
#   faces        -8.833
#   wine         -8.833
#   congo        -8.140
#   formation    -8.833
#   subcommittee -8.833
#   tensioning   -8.833
#   temporary    -8.833
#   furor        -8.833
#   unshielded   -8.833
#   deerstalker  -8.833
#   arguments    -8.833
#   wager        -8.833
#   mushrooming  -8.833
#   rebs         -8.833
#   move         -8.833
#   recently     -8.833
#   freeway      -8.833
#   guerrilla    -8.833
#   diurnal      -8.833
#   railroads    -8.833
#   commotion    -8.833
#   dances       -8.833
#   box          -8.833
#   collector    -8.833

# %%
def sample_next_words(context, get_next_word, k=5, temperature=1.0):

    if context not in get_next_word:
        return ["<unknown>"] * k

    next_logps = get_next_word[context]
    words = list(next_logps.keys())
    logps = np.array(list(next_logps.values()), dtype=float)

    scaled = logps / temperature

    probs = np.exp(scaled - np.max(scaled))
    probs /= probs.sum()

    return list(np.random.choice(words, size=k, p=probs, replace=True))


contexts = [
    ('<s>',),
    ('the',),
    ('<s>', 'the')
]

for ctx in contexts:
    next_words = sample_next_words(ctx, get_next_word, k=5)
    print(f"Context {ctx} -> Next words: {next_words}")

a1 = sample_next_words(('<s>', 'the'), get_next_word, k=5)
print(a1)
# Out:
# Context ('<s>',) -> Next words: [np.str_('they'), np.str_('what'), np.str_('in'), np.str_('rangoni'), np.str_('you')]
# Context ('the',) -> Next words: [np.str_('alert'), np.str_('only'), np.str_('flannagans'), np.str_('sun'), np.str_('impression')]
# Context ('<s>', 'the') -> Next words: [np.str_('disasters'), np.str_('film'), np.str_('amateur'), np.str_('latest'), np.str_('reactionary')]
# [np.str_('language'), np.str_('round'), np.str_('situation'), np.str_('conductor'), np.str_('orchestra')]

# %% [markdown]
# ### Graded Question:
#
# In the next cell, set `a1` to the list of 5 next words for the trigram context `('<s>','the')` (unlikely, but you may have to adjust `num_sentences` as indicated).

# %%
# Your answer here

a1 = ['language','round', 'situation', 'conductor', 'orchestra']

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a1 in this problem

print(f'a1 = {a1}')
# Out:
# a1 = ['language', 'round', 'situation', 'conductor', 'orchestra']

# %% [markdown]
# ## Problem Two: Generating Sentences with Backoff and Temperature
#
#
# The algorithm for generating sentences from a N-Gram PLM is simple: look at the last $N-1$ tokens of the sentence and use the probability distribution of next words to select the continuation word; stop when you generate `'</s>'`.
#
#
# For **bigrams**, this works well: Every token in the text is followed by another token (because `</s>` ends every sentence).
#
# However there are two problems when using N-grams for $N>2$:
#
# **1. Cold Start (not enough left-context):**  You don't have enough left context in the beginning, so you start with what you have until you have enough left context.   For example, with trigrams:
#
#                                           Find next word using:
#         Step 1:    <s> ?                      bigrams
#          context:  ---
#         Step 2:    <s> One ?                  trigrams
#          context:  ------
#         Step 3:    <s> One ish ?             continue on with trigrams
#          context:      ---------
#
#
# **2. Sparsity (not enough N-grams):** For bigrams we always have a continuation for the left context (1 token). However, it is possible for $N>2$ that there is no N-gram which gives you a choice of next words, for example, suppose your sentence so far is
#
#             "One fish dish ..."
#
# and there is no trigram in the form `("fish", "dish", ...)`. In this case we use the **backoff** strategy: if there is no trigram left-context `("fish", "dish")`,
# cut out one token and use the (safe) bigram strategy with left context `("dish",)`.  In general, for any $N$,
# if $N$ does not provide a next word, try $N-1$, $N-2$ etc. until one is found (in the worse case,
# for $N=1$, you'll just select a likely word without any left-context, but note that with boundary tokens, you'll
# always have a bigram).
#
#
# **ToDo:**
#
# - Adapt the code for generating sentences from the Coding Video to perform the backoff strategy just described, and using your code from Problem One.
# - Make sure you convert the log probabilities **back into non-log probabilities before you use them as weights in in `np.choice(..., p=weights)`**.
# - Perform 3 experiments with temperature set at 0.2, 1.0, and 5.0 **with the full dataset if possible**:
#     - Generate 10 sentences for each temperature, print them out using `print_sentence` and observe whatever differences you can.
# - Answer the graded questions.

# %%
# Your code here (add as many cells as you need)
def sample_from_context(context, get_next_word, temperature=1.0):

    while context and context not in get_next_word:
        context = context[1:]
    if not context:
        context = random.choice(list(get_next_word.keys()))

    log_probs = get_next_word[context]
    words = list(log_probs.keys())
    logps = np.array(list(log_probs.values()), dtype=float)

    scaled = logps / temperature

    probs = np.exp(scaled - np.max(scaled))
    probs /= probs.sum()

    return np.random.choice(words, p=probs)


def generate_sentence(get_next_word, temperature=1.0, max_len=30):

    tokens = ['<s>']

    while len(tokens) < max_len:
        if len(tokens) >= 2:
            context = tuple(tokens[-2:])
        else:
            context = tuple(tokens[-1:])

        next_word = sample_from_context(context, get_next_word, temperature)

        tokens.append(next_word)

        if next_word == '</s>':
            break

    return tokens


temperatures = [0.2, 1.0, 5.0]

for T in temperatures:
    print(f"\n=== Temperature = {T} ===")
    for i in range(10):
        sent_tokens = generate_sentence(get_next_word, temperature=T)
        print_sentence(sent_tokens)
# Out:
# === Temperature = 0.2 ===
# The man who had been a good deal of thought and emotion when interpreted as the`` I'm not going to be a good deal of their
# The first time in the world.
# The first time, and the other hand, the first time in the first time in the world.
# The first time in the first time in the last few years.
# The new york, and the other hand, the first time in the first time in the first time in the same time, and the other hand
# The first time in the world.
# The first time in the world.
# The other hand, the first time, and the fact that the united states, and the`` I have never been a good deal of time
# The first time in the world.
# The only way to the editor:
#
# === Temperature = 1.0 ===
# It was an open and tried to get in the dirt in front of the more convinced I became fifteen, was crisscrossed with wrinkles, as gannett's
# He claims mahzeer's office and drugstore at the boss's wife for him to name but two rows of animals was horrifying, ranging from appointments to jobs
# Blockade runners can be obtained without a comment which fits the pattern suggested here, and other cholesterol- rich wealth, a district co- ordination of the
# Second, to 360,000 and 270,000 by the young and limp.
# Few writers have certainly done little more than president eisenhower and john cool and moist and protects it from fusing with the communist yoke of opinion is supported by
# Now spencer, seeming at first for spring of 1925 for national library week, secretary;;
# If I should like to wander'', felix proclaimed.
# That we will concentrate on current measures which are so tired -- I think you can go any place he had one pistol in a little more than cordial
# During the period after the death camps, a whole.
# Whoever is born of the biblical view of society exists only on the market tops out when you make to any school, 3505o dequindre, which had`
#
# === Temperature = 5.0 ===
# Boniface was later promoted to archangel, ranking with- but- after- day fast in which moscow had complete superiority in argument over a number.
# Sailing activity is halfway between the armed messenger from burlington at fort sumter is home sick in the gateway shopping center may seem artificially arbitrary,`` third
# Arriving at a new series of sherlock holmes adventures ends with holmes and his montenegrin lady.
# Land, pont kehl, on** ymg per day as a vintner knows a vintage.
# Gladden's home, and bolingbroke advised that it melted the window looked out over the entire epic corpus that may occupy the right with him in his pajamas
# Opinion is that under no circumstances would he work at home''.
# Wants to get better flowers than the north american species is bumblebees and can always file a declaration of rights'' orientation.
# Movements unfold freely because they are surely conformists.
# Believing devoutly as they neared the surface temperature gradient af at the way dentists recommend.
# Based on swadesh's second shot.

# %% [markdown]
# ### Graded Questions:
#
# #### Part 2A: In the next cell, set `a2a` to the *most realistic sentence* generated (your call!). Use `print_sentence(..., do_print=False)`.

# %%
# Your answer here

a2a = 'The first time in the world.'

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a2a in this problem

print(f'a2a = {a2a}')
# Out:
# a2a = The first time in the world.

# %% [markdown]
# #### Part 2B:  Describe in a few sentences what you observed with the different temperature settings (and try more if you wish!). Which seemed to produce the most realistic sentences?
#
# Your answer here:

# %% [markdown]
# At a low temperature, the generator produced short, repetitive sentences albeit with proper grammar for the most part compared to the other temperatures. They were the most realistic, but lacked variety and often repeated the same phrases. As temperature increased, the sentences became longer and word choice became more varied, but the grammar did deteriorate, with many of the sentences becoming incoherent. To find a balance between proper grammar/sentence structure and variety, best temperature likely falls somewhere in between 0.2 and 1.0.

# %% [markdown]
# ## Problem Three:  Measuring the Quality of Sentences:  Average Log Probability and Perplexity
#
# The probabilities involved when we start to calculate the probability of longer token sequences are extremely small, and underflow is common
# for a large corpus. Therefore we calculate all probabilities in **log space** (see **Appendix Two** for an explanation).
#
# Basically, the quality metric for generated sentences is likelihood: If a sentence is more probable, it is better.
# However, this metric is biased towards short sentences, since we multiply the probabilities of each word,
# and long sentences end up being very unlikely. But natural language does not behave this way!
#
# Therefore, we will remove the length from the calculation using the following measures:
#
# **Average of Log Probabilities (ALP)** is a length-agnostic measure of sentence probability. For trigrams:
#
# Let the tokenized sentence be $[t_1,\ldots,t_n]$ with $t_1$ = `<s>` and $t_n$ = `</s>`.
#
#
# $$
# \text{ALP}([t_1, t_2, \dots, t_n])
# \ =\ \frac{\log P(t_2 \mid t_1) + \log P(t_3 \mid t_1, t_2) + \dots + \log P(t_n \mid t_{n-2}, t_{n-1})}{n-1}
# $$
#
# **Notes:**
# - We don't include the first token because it is always present and hence not predicted; think of
# it as a prompt which gets the sentence going!
# - To account for backoff, simply use the log probability of the bigram in those cases instead of the trigram.
# - ALP is in $(-\infty \ldots 0.0]$ and larger is better.  It grows more negative as the model performs worse.
#
#
# **Perplexity** is the most common metric in NLP: it rescales the ALP into a more intuitive, positive scale:
#
# > Perplexity = np.exp( - ALP ).
#
# Perplexities are $\ge 1.0$ and smaller is better.   A larger perplexity means the model is “more perplexed,” i.e., on average it is choosing among more equally likely alternatives.
#
# Because the exponential is monotonic, minimizing perplexity is exactly the same as maximizing average log probability—so either metric may be used for ranking models, but perplexity is more commonly used by the NLP community.
#
# ### Before You Start
#
# You can compute ALP during generation by carrying **state** along with the partial sentence.
# Instead of storing:
#
# > tokens_so_far = [ `<s>`, $t_2$, $t_3$, … ]
#
# store a **pair**:
#
# > ( tokens_so_far, sum_log_probs)
#
# where
#
# * **sum_log_probs** = $( \log P(t_2\mid t_1) + \log P(t_3\mid t_1,t_2) + \cdots )$
#
# In the case that backoff was used to generate some $t_k$, you just use $\log P(t_{k}\mid t_{k-1})$
#
# Then your loop is:
#
# 1. Start with tokens = `['<s>']` and `sum_log_probs = 0.0`.
# 2. Get the left context (trigram preferred; back off to bigram if needed).
# 3. **Sample** the next token using temperature, but **score** with the model’s **true** log-prob for that token (un-tempered): update `sum_log_probs += log P(next|context)`.
# 4. Append the token; if it is `</s>`, stop, else repeat froms step 2.
# 5. Calculate the perplexity of the completed sentence:
# - Divide the running sum of log probabilities by `len(tokens)-1` to get the final ALP.
# - Calculate `PP = np.exp(-ALP)` and return the pair `( completed-list-of-tokens, PP)` as the generated sentence.
#
#
#
# ### To Do
#
# * Modify your `get_next_word` and sentence generator method to maintain `(tokens, sum_log)` as above and return `(tokens, Perplexity)`.
# - Perform 3 experiments with temperature set at 0.2, 1.0, and 5.0 **with the full dataset if possible**:
#     - Generate 10 sentences for each temperature, print them out using `print_sentence` and observe whatever differences you can, comparing them with the perplexity.
# * Answer the graded questions.

# %%
# Your code here: add as many cells as you wish
def generate_sentence_with_perplexity(get_next_word, temperature=1.0, max_len=30):
    tokens = ['<s>']
    sum_log_probs = 0.0

    while len(tokens) < max_len:
        if len(tokens) >= 2:
            context = tuple(tokens[-2:])
        else:
            context = tuple(tokens[-1:])

        used_context = context
        while used_context and used_context not in get_next_word:
            used_context = used_context[1:]
        if not used_context:
            used_context = random.choice(list(get_next_word.keys()))

        base_log_probs = get_next_word[used_context]
        words = list(base_log_probs.keys())
        logps = np.array(list(base_log_probs.values()), dtype=float)

        word2logp = dict(zip(words, logps))

        scaled = logps / temperature
        probs = np.exp(scaled - np.max(scaled))
        probs /= probs.sum()

        next_token = np.random.choice(words, p=probs)

        true_logp = word2logp[next_token]
        sum_log_probs += true_logp

        tokens.append(next_token)
        if next_token == '</s>':
            break

    alp = sum_log_probs / (len(tokens) - 1)
    perplexity = np.exp(-alp)
    return tokens, perplexity


temperatures = [0.2, 1.0, 5.0]

for T in temperatures:
    print(f"\n=== Temperature = {T} ===")
    results = []
    for i in range(10):
        sent_tokens, PP = generate_sentence_with_perplexity(get_next_word, temperature=T)
        sentence = print_sentence(sent_tokens, do_print=False)
        results.append((sentence, PP))
        print(f"{sentence}   (Perplexity: {PP:.2f})")

    mean_pp = np.mean([pp for _, pp in results])
    print(f"\nAverage perplexity @ T={T}: {mean_pp:.2f}")
# Out:
# === Temperature = 0.2 ===
# The first time in the world, but he was a good deal of attention, he said,`` I do n't know what we are not   (Perplexity: 7.77)
# The first time in the world.   (Perplexity: 8.94)
# The first two years ago, and the other hand, the first time in the first time.   (Perplexity: 9.82)
# The first time in the united states of america, where the boys are''!!   (Perplexity: 6.56)
# The first time in the world.   (Perplexity: 8.94)
# The first time in the field, the first time in the first time in the united states, and the two of them, and the whole world   (Perplexity: 13.15)
# The most important thing was to be a`` I'm not going to be a`` I'm not going to be a`` I   (Perplexity: 7.70)
# The first time in the first time in the world.   (Perplexity: 9.56)
# He was a good deal of their own.   (Perplexity: 10.23)
# The first time in the world.   (Perplexity: 8.94)
#
# Average perplexity @ T=0.2: 9.16
#
# === Temperature = 1.0 ===
# But the removal process.   (Perplexity: 11.12)
# Chicago, some good infield play.   (Perplexity: 10.55)
# Thus he would never have thought I ought to be a good feeling prevailed on the dynamics of population was not opposed to fully company- paid workers in   (Perplexity: 7.91)
# They had to be important now.   (Perplexity: 11.16)
# It, he would be paid.   (Perplexity: 37.55)
# Electrostatic systems of the common misconception that he personally`` I'll take them away and survive to this title.   (Perplexity: 10.68)
# Resentment welled up yesterday among democratic district leaders and`` this one, and white tile, acoustical tile, ceramics or similar arts and television,`   (Perplexity: 5.35)
# `` just and reasonable attorney's fees as a substitute, the tours of tokyo.   (Perplexity: 6.12)
# Measurements of materials can be made, the senate.   (Perplexity: 19.96)
# Muller's second cousin was an essential part of his earning potential by taking a stand.   (Perplexity: 8.21)
#
# Average perplexity @ T=1.0: 12.86
#
# === Temperature = 5.0 ===
# Funny how seldom they did they could foresee that that return is also threatening to swallow.   (Perplexity: 6.63)
# Oranges and grapefruit are shipped from florida to cuba'', phil said:' all is a passionate consciousness grasped and squeezed out the battered stetson.   (Perplexity: 4.76)
# Haydn c. covington argued the cause- and- glass chancery of the inconsistencies revolving about the grand styles of recitative sensitively attuned to the mackinac straits, while   (Perplexity: 5.34)
# Conflict surveyed   (Perplexity: 38.56)
# Necessary retouching was put out her life, not dead.   (Perplexity: 13.51)
# Colorado's grand canyon, probably very few wives'' at intervals in some rates, general business activity this year, reports from ministries around the cuff of   (Perplexity: 6.11)
# Decorated on unfired glaze with one's command, suffered its greatest security??   (Perplexity: 4.88)
# Ornament is confabulation in the sign.   (Perplexity: 13.77)
# Tim is, not significantly altered by establishing as conditions for happiness, and active duty as an incentive to self- exile since 1952.   (Perplexity: 7.13)
# Insurance   (Perplexity: 169.32)
#
# Average perplexity @ T=5.0: 27.00

# %% [markdown]
# ### Graded Questions:
#
# #### Part 3A: In the next cell, set `a3a` to the sentence with the smallest perplexity. Use `print_sentence(..., do_print=False)`.

# %%
# Your answer here

a3a = "Oranges and grapefruit are shipped from florida to cuba'', phil said:' all is a passionate consciousness grasped and squeezed out the battered stetson."

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a3a
print(f'a3a = {a3a}')
# Out:
# a3a = Oranges and grapefruit are shipped from florida to cuba'', phil said:' all is a passionate consciousness grasped and squeezed out the battered stetson.

# %% [markdown]
# #### Part 3B:  Set `a3b` to the perplexity for the sentence you provided in Part 3A.

# %%
# Your answer here

a3b = 4.76

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a1 in this problem

print(f'a3b = {a3b}')
# Out:
# a3b = 4.76

# %% [markdown]
# #### Part 3C:  Describe in a few sentences what you observed with the different temperature settings (and try more if you wish!). Which produces the sentences with the best perplexity (you might want to take the average of all 10!).
#
# Your answer here:

# %% [markdown]
# As seen across the average perplexities, lower temperatures produced sentences with lower perplexities and vice versa for the higher temperature results. This indicates that the model is more confident in the shorter, structured sentences and acts with more certainty. Interestingly though, the sentence with the smallest perplexity was in the temperature = 5 group. As seen in the above sentence, the grammar and punctuation is off but the first half of the sentence is very coherent before transitioning into a less coherent second half.

# %% [markdown]
# ## Problem Four:  Beam Search
#
# For our final problem, we'll implement a common technique for searching for sentences with low perplexity.
#
# **Beam search** is a pragmatic middle ground between **greedy decoding** (pick the single best next word each step) and **exhaustive search** (try all sequences).
#
# ![Screenshot 2025-10-04 at 12.12.48 PM.png](attachment:224d4777-a5b9-4360-9cc3-5651367faeb0.png)
#
# The basic idea is reasonably simple:
#
# Maintain a list of at most **B** incomplete sentences, sorted in **decreasing order of their ALP (best at the top)**; you'll need to calculate this during the sort, or perhaps store a triple
# > (list-of-tokens, sum-of-log-probs, ALP-so-far)
#
# where
# > ALP-so-far =sum-of-log-probs/(len(list-of-tokens)-1)
#
# **In detail:**
#
# Initialize a priority queue `PQ = [ ['<s>'],0.0] ]`
#
# 1. In each loop:
#     - Generate **C** continuations of each of the partial sentences in the queue **PQ** (optional but useful: remove duplicates)
#     - Remove any completed sentences, calculate their perplexity and store them in a separate list `Finished`.
#     - Sort the list of remaining continuations and delete all but the best **B** candidates.
#     - Replace **PQ** with this list of new candidates.
# 3. Repeat from step 1 until you get 10 finished sentences in `Finished` or simply iterate 100 times.
# 4. Sort the list `Finished` in increasing order of perplexity and print it out.
#
#   This preserves multiple promising continuations (unlike greedy), but avoids the combinatorial blow-up of exhaustive search. Using **log-probs** makes scoring stable; using a **length-normalized** score (ALP) prevents the search from favoring short fragments. Beam width (B) controls the trade-off: larger (B) explores more but costs more time and can still prune good paths too early. Continuation width (C) controls how widely you search possible continuations, and uses temperature.
#
# **ToDo:**
#
# - Implement beam search as described, using $B=C=5$.
# - Experiment with temperatures of 0.2, 1.0, and 5.0 as before.
# - Print out your finished sentences with perplexities.
# - Answer the graded questions.

# %%
# Your code here; add as many cells as you wish

def beam_search(get_next_word, beam_width=5, cont_width=5, temperature=1.0, max_len=30):

    PQ = [(['<s>'], 0.0)]
    Finished = []

    for step in range(max_len):

        new_candidates = []

        for tokens, sum_log in PQ:

            if tokens[-1] == '</s>':
                alp = sum_log / (len(tokens) - 1)
                perplexity = np.exp(-alp)
                Finished.append((tokens, perplexity))
                continue

            if len(tokens) >= 2:
                context = tuple(tokens[-2:])
            else:
                context = tuple(tokens[-1:])

            used_context = context
            while used_context and used_context not in get_next_word:
                used_context = used_context[1:]
            if not used_context:
                used_context = random.choice(list(get_next_word.keys()))

            base_log_probs = get_next_word[used_context]
            words = list(base_log_probs.keys())
            logps = np.array(list(base_log_probs.values()), dtype=float)
            word2logp = dict(zip(words, logps))

            scaled = logps / temperature
            probs = np.exp(scaled - np.max(scaled))
            probs /= probs.sum()

            top_idx = np.argsort(-probs)[:cont_width]
            for idx in top_idx:
                w = words[idx]
                lp = word2logp[w]
                new_tokens = tokens + [w]
                new_sum_log = sum_log + lp
                new_candidates.append((new_tokens, new_sum_log))

        scored = []
        for toks, s_log in new_candidates:
            alp_so_far = s_log / (len(toks) - 1)
            scored.append((alp_so_far, toks, s_log))

        scored.sort(key=lambda x: x[0], reverse=True)
        PQ = [(t, s) for _, t, s in scored[:beam_width]]

        if len(Finished) >= 10:
            break

    Final = []
    for tokens, _ in Finished:
        sum_log = 0.0
        for i in range(1, len(tokens)):
            context = tuple(tokens[max(0, i-2):i])
            while context and context not in get_next_word:
                context = context[1:]
            if not context:
                context = random.choice(list(get_next_word.keys()))
            logp = get_next_word[context].get(tokens[i], -999)
            sum_log += logp
        alp = sum_log / (len(tokens) - 1)
        perplexity = np.exp(-alp)
        Final.append((tokens, perplexity))

    Final.sort(key=lambda x: x[1])
    return Final

# %%
temperatures = [0.2, 1.0, 5.0]

for T in temperatures:
    print(f"\n=== Beam Search Results (Temperature={T}) ===")
    results = beam_search(get_next_word, beam_width=5, cont_width=5, temperature=T)

    for sent_tokens, PP in results[:10]:
        sent = print_sentence(sent_tokens, do_print=False)
        print(f"{sent}   (Perplexity: {PP:.2f})")

    mean_pp = np.mean([pp for _, pp in results])
    print(f"Average perplexity @ T={T}: {mean_pp:.2f}")
# Out:
# === Beam Search Results (Temperature=0.2) ===
# `` I do n't know how to feed: beef cattle( finishing ration)   (Perplexity: 3.28)
# `` I do n't know how to feed: beef cattle:( 1).   (Perplexity: 3.39)
# `` I do n't know how to feed: beef cattle:( 1)   (Perplexity: 3.55)
# `` I do n't know how to feed: beef cattle.   (Perplexity: 4.02)
# `` I do n't know how to feed: beef cattle:( 1) the need for a while.   (Perplexity: 4.16)
# `` I do n't know how to feed:   (Perplexity: 4.28)
# `` I do n't know what to do so.   (Perplexity: 4.38)
# `` I do n't know what to do.   (Perplexity: 4.39)
# `` I do n't know.   (Perplexity: 4.60)
# `` I do n't know how to feed: beef   (Perplexity: 4.63)
# Average perplexity @ T=0.2: 4.07
#
# === Beam Search Results (Temperature=1.0) ===
# `` I do n't know how to feed: beef cattle( finishing ration)   (Perplexity: 3.28)
# `` I do n't know how to feed: beef cattle:( 1).   (Perplexity: 3.39)
# `` I do n't know how to feed: beef cattle:( 1)   (Perplexity: 3.55)
# `` I do n't know how to feed: beef cattle.   (Perplexity: 4.02)
# `` I do n't know how to feed: beef cattle:( 1) the need for a while.   (Perplexity: 4.16)
# `` I do n't know how to feed:   (Perplexity: 4.28)
# `` I do n't know what to do so.   (Perplexity: 4.38)
# `` I do n't know what to do.   (Perplexity: 4.39)
# `` I do n't know.   (Perplexity: 4.60)
# `` I do n't know how to feed: beef   (Perplexity: 4.63)
# Average perplexity @ T=1.0: 4.07
#
# === Beam Search Results (Temperature=5.0) ===
# `` I do n't know how to feed: beef cattle( finishing ration)   (Perplexity: 3.28)
# `` I do n't know how to feed: beef cattle:( 1).   (Perplexity: 3.39)
# `` I do n't know how to feed: beef cattle:( 1)   (Perplexity: 3.55)
# `` I do n't know how to feed: beef cattle.   (Perplexity: 4.02)
# `` I do n't know how to feed: beef cattle:( 1) the need for a while.   (Perplexity: 4.16)
# `` I do n't know how to feed:   (Perplexity: 4.28)
# `` I do n't know what to do so.   (Perplexity: 4.38)
# `` I do n't know what to do.   (Perplexity: 4.39)
# `` I do n't know.   (Perplexity: 4.60)
# `` I do n't know how to feed: beef   (Perplexity: 4.63)
# Average perplexity @ T=5.0: 4.07

# %% [markdown]
# ### Graded Questions:
#
# #### Part 4A: In the next cell, set `a4a` to the sentence with the smallest perplexity generated by beam search. Use `print_sentence(..., do_print=False)`.

# %%
# Your answer here

a4a = "`` I do n't know how to feed: beef cattle( finishing ration)"

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a3a
print(f'a4a = {a4a}')
# Out:
# a4a = `` I do n't know how to feed: beef cattle( finishing ration)

# %% [markdown]
# #### Part 4B:  Set `a4b` to the perplexity for the sentence you provided in Part 4A.

# %%
# Your answer here

a4b = 3.28

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a4b in this problem

print(f'a4b = {a4b}')
# Out:
# a4b = 3.28

# %% [markdown]
# #### Part 4C:  Describe in a few sentences what you observed with the different temperature settings (and try more if you wish!). Which produces the sentences with the best perplexity (you might want to take the average of all 5!).
#
# Your answer here:

# %% [markdown]
# Interestingly, the temperature changes did not change the generated sentences as seen in the previous experiments. This could be due to beam search using deterministic ranking, not random sampling. Temperature scales the probabilities but the rankings remain the same, resulting in identical beams. In other words, it seems that the temperature is adjusting the magnitudes but not the choices of the words themselves.

# %% [markdown]
# ## Appendix One: The Brown Corpus
#
# The **Brown Corpus of Standard American English** was compiled at **Brown University** by W. Nelson Francis and Henry Kučera in 1961. It was the **first electronic, balanced corpus of English** ever created and contains about **one million words** drawn from **500 written texts** published in the United States in 1961.
#
# At the time, this was groundbreaking: instead of studying isolated examples, linguists and computer scientists could analyze the **statistical properties of language** across many genres. The Brown Corpus became a **benchmark dataset** in early computational linguistics, psycholinguistics, and later in natural language processing.
#
# ### Genres in the Brown Corpus
#
# The 500 texts were divided evenly across **15 categories**, each representing a different register or style of writing:
#
# * **Press**: reportage, editorials, reviews
# * **General prose**: popular lore, belles lettres, essays
# * **Fiction**: adventure, romance, science fiction, mystery, humor
# * **Learned writing**: academic and scientific publications
# * **Religious writing**: sermons, expository texts
# * **Skills and hobbies**: manuals, do-it-yourself, gardening, sports writing
# * **Government documents**: official reports, public affairs writing
# * **Miscellaneous**: popularized non-fiction, biography
#
# Each category contributes about 2,000 sentences (roughly 80,000 words), ensuring a **balanced sample** of contemporary written English.
#
# ### Examples of Source Texts
#
# While the Brown Corpus does not preserve full books in sequence, the selections were drawn from published works of the time. Examples include:
#
# * **Fiction**: pulp magazines, detective novels, romance stories, humorous fiction.
# * **Press**: articles from major U.S. newspapers and magazines such as *Time* and *Newsweek*.
# * **Religion**: sermons, Bible commentary, religious essays.
# * **Academic**: journal articles in history, sociology, psychology, and linguistics.
# * **Skills and hobbies**: popular magazines like *Popular Mechanics* and *Field & Stream*.
#
# The corpus thus reflects a **snapshot of American English in 1961**: how it was written in popular culture, journalism, science, religion, and government.
#
# ### Why It Matters
#
# * **Historical importance**: the first large corpus, setting the stage for all later corpus linguistics.
# * **Balanced design**: unlike modern web scrapes (e.g., Wikipedia), Brown was carefully curated to capture a **cross-section of genres**.
# * **Still used today**: it remains a teaching resource for exploring **word frequencies, n-grams, Zipf’s law, and stylistic differences across genres**.
#
# ### Categories in the Brown Corpus
#
# The Brown Corpus is divided into 15 genres, each with about 80,000 words (for a total of ~1 million). This balance makes it useful for studying stylistic and lexical variation across English.
#
# | Code | Category              | Description / Examples                                  |
# |------|-----------------------|---------------------------------------------------------|
# | A    | Press: Reportage      | Straight news reporting; newspaper and magazine articles |
# | B    | Press: Editorial      | Opinion pieces and editorials from newspapers/magazines |
# | C    | Press: Reviews        | Reviews of books, plays, music, films                   |
# | D    | Religion              | Sermons, religious commentary, Bible studies            |
# | E    | Skills & Hobbies      | How-to manuals, sports, leisure, do-it-yourself         |
# | F    | Popular Lore          | Popular science, cultural essays, lore                  |
# | G    | Belles Lettres        | Literary essays, non-fiction with artistic style        |
# | H    | Miscellaneous         | Biographies, memoirs, other non-fiction                 |
# | J    | Learned               | Academic and scientific writing                         |
# | K    | General Fiction       | Short stories and novels, general fiction               |
# | L    | Mystery & Detective   | Detective and crime fiction                             |
# | M    | Science Fiction       | Science fiction stories and novels                      |
# | N    | Adventure & Western   | Adventure stories, Westerns                             |
# | P    | Romance               | Romantic fiction                                        |
# | R    | Humor                 | Humorous fiction and essays                             |
#
# Together these categories provide a **snapshot of American English in 1961**, from journalism and government reports to pulp fiction and academic writing.

# %%
for p in [1,1/2,1/3,1/4, 0.01, 1e-10]:
          print(math.log(p))
# Out:
# 0.0
# -0.6931471805599453
# -1.0986122886681098
# -1.3862943611198906
# -4.605170185988091
# -23.025850929940457

# %% [markdown]
# ## Appendix Two: Using Log-Probabilities in N-Gram Models
#
# When working with **n-gram language models**, we calculate the probability of a sentence by multiplying the conditional probabilities of each word:
#
# $$
# P(w_1, w_2, \dots, w_n) = \prod_{i=1}^n P(w_i \mid \text{context})
# $$
#
# ### Do we really need logs for the Brown Corpus?
#
# In the Brown Corpus, the **longest sentence has 182 tokens**. That’s not very long compared to modern corpora, so you might think multiplying probabilities directly is fine. For example:
#
# * If the average conditional probability were around $0.1$, the longest Brown sentence has probability about
#   $$(0.1)^{182} = 10^{-182},$$
#   which is still representable in double precision (smallest positive $\approx 10^{-324}$).
#
# * But if the average probability were closer to $0.01$, then
#   $$(0.01)^{182} = 10^{-364},$$
#   which would **underflow to 0**.
#
# So in some cases you’d be safe, in others not.
#
# ### Some Examples of Log Probabilities
#
# Since probabilities are always in the range $[0,1.0]$, log probabilities are in the range $[-\infty,0.0]$. Here are
# some examples of log probabilities (we'll use natural logs, but the base really doesn't matter):
#
#     Probability         Log Probability
#       1.0                 0.0
#       1/2                -0.6931471805599453
#       1/3                -1.0986122886681098
#       1/4                -1.3862943611198906
#       0.01               -4.605170185988091
#       1e-10              -23.025850929940457
#       1e-1000            -2302.5850929940457
#
# (To put this in somewhat real terms, suppose you and a friend could both randomly choose an **atom** somewhere in the observable
# universe: the probability that you both choose the same atom is approximately 1e-80.)
#
# ### Why we use log-probabilities anyway
#
# Even if underflow is not common in Brown sentences, there are three strong reasons to switch to log-space:
#
# 1. **Smoothing produces tiny probabilities.** With add-one or Kneser–Ney smoothing, many n-grams have very small values, making underflow more likely.
# 2. **Corpus-level calculations.** Perplexity is often computed over *all tokens* in the corpus. With Brown’s ~1M tokens, multiplying raw probabilities is completely impossible.
# 3. **Consistency with NLP practice.** Modern language models (n-gram and neural alike) always work in log-space. Teaching it here ensures the method scales to larger datasets like Shakespeare, WikiText, or web-scale corpora.
#
# ### The log-space trick
#
# Recall how computing in log-space works:
#
# - Convert your numbers to logs
# - Instead of multiplying, add
# - Instead of exponentiation, multiply
# - If you need to sort, or compare using $\lt$ or $\le$, just do it in log-space (since it is monotonic, i.e., preserves order)
# - Convert back to normal if you want to print it out in human-readable form as a metric or use it with code that expects normal probabilities (e.g., softmax, or sampling).
#
# Thus, instead of multiplying probabilities, we sum log probabilities:
#
# $$
# \log P(w_1, w_2, \dots, w_n) = \sum_{i=1}^n \log P(w_i \mid \text{context})
# $$
#
# This prevents underflow, keeps values in a manageable numeric range, and makes computation easier.
#
# * **Ranking:** For decoding or beam search, you can use log-probabilities directly, since $\log$ is monotonic. No conversion back is needed.
# * **Perplexity:**
#
# $$
# \text{PP} = \exp\left(-\tfrac{1}{n} \sum_{i=1}^n \log P(w_i \mid \text{context})\right)
# $$
#
# Here the exponential is applied only at the end.
#
# * **Sampling:** To draw the next word, convert log-probabilities back with `exp()` to normalize.
#
# ---
#
# ✅ **TL;DR Summary:** In the Brown Corpus, you *might* get away with raw probabilities for single sentences, but log-space is essential once you apply smoothing, compute perplexity over the whole corpus, or move to larger datasets. It’s also the standard method in NLP, so it’s best to learn it now.
