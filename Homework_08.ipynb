# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0280 - mae: 0.1277 - rmse: 0.1673 - val_loss: 0.0194 - val_mae: 0.0982 - val_rmse: 0.1392
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Selected epoch: 19 (min val_loss)
# Valid @ sel —  MAE: 0.09935 | RMSE: 0.1352 (scaled)
# Train @ sel —  MAE: 0.1384  | RMSE: 0.1821 (scaled)

# %% [markdown]
# ### Now we'll demonstrate the model's predictive power on the last 2 weeks of the test samples

# %%
def evaluate_on_test(
    model,
    *,
    target_scaler=None,          # pass your y scaler here if you want original units
    report_in_scaled=True,       # set False to invert to original units
    unit_scaled="(scaled)",
    unit_original="MW",          # or "MWh" if your target is energy, not power
    plot_last_hours=24*7,
):
    """
    Evaluate on X_test/y_test and plot the last `plot_last_hours` predictions.
    Supports horizon=1 and direct multi-output (H>1).
    """
    # 1) Predict
    y_pred = model.predict(X_test, verbose=0)         # (n_windows, H) or (n_windows, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred[:, None]
    H = y_pred.shape[1]

    # 2) Choose units (scaled vs original)
    def maybe_invert(arr):
        if report_in_scaled or target_scaler is None:
            return arr
        a = np.asarray(arr).reshape(-1, 1)
        return target_scaler.inverse_transform(a).ravel()

    # 3) Build comparable arrays for metrics
    # y_test matches y_pred shape: (n_windows, H)
    y_true = y_test
    # Metrics (per-horizon and averaged) in chosen units
    err = maybe_invert(y_pred.ravel()) - maybe_invert(y_true.ravel())
    rmse_avg = float(np.sqrt(np.mean(err**2)))
    mae_avg  = float(np.mean(np.abs(err)))

    if H > 1:
        # per-horizon
        y_true_u = maybe_invert(y_true)
        y_pred_u = maybe_invert(y_pred)
        mae_per_h  = np.mean(np.abs(y_true_u - y_pred_u), axis=0)
        rmse_per_h = np.sqrt(np.mean((y_true_u - y_pred_u)**2, axis=0))

    # 4) Prepare a single timeline for plotting
    def stitch_direct_predictions(yhat):
        """Average overlaps for direct multi-step predictions."""
        n, HH = yhat.shape
        total = n + HH - 1
        out = np.zeros(total, dtype=float)
        cnt = np.zeros(total, dtype=float)
        for i in range(n):
            out[i:i+HH] += yhat[i]
            cnt[i:i+HH] += 1.0
        return out / np.maximum(cnt, 1.0)

    # Choose units for plotting
    unit = unit_scaled if (report_in_scaled or target_scaler is None) else unit_original

    if H == 1:
        y_true_t = maybe_invert(y_true.ravel())
        y_pred_t = maybe_invert(y_pred.ravel())
    else:
        # stitch both for a continuous timeline
        y_pred_t = stitch_direct_predictions(maybe_invert(y_pred))
        y_true_t = stitch_direct_predictions(maybe_invert(y_true))

    # 5) Print summary
    print(f"Test RMSE (avg over all steps): {rmse_avg:,.3f} {unit}")
    print(f"Test  MAE (avg over all steps): {mae_avg:,.3f} {unit}")
    if H > 1:
        print("Per-horizon (0 = 1-step ahead):")
        print("  MAE :", np.round(mae_per_h, 3))
        print("  RMSE:", np.round(rmse_per_h, 3))

    # 6) Plot last N hours
    N = min(plot_last_hours, len(y_true_t))
    plt.figure(figsize=(14, 6))
    plt.title("Test — Last 7 Days: Truth vs Forecast")
    plt.plot(y_true_t[-N:], label="Truth")
    plt.plot(y_pred_t[-N:], label="Predicted", linestyle="--")
    plt.xlabel("Hour")
    plt.ylabel(unit)
    plt.grid(True, axis='y', linestyle=':', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    plt.show()

evaluate_on_test(baseline_model)
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bc85a6c6e80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Test RMSE (avg over all steps): 0.107 (scaled)
# Test  MAE (avg over all steps): 0.090 (scaled)

# %% [markdown]
# ## Problem One — Exploring Lookback and Horizon
#
# Experiment with different combinations of `lookback` and `horizon` values.
# For example, you might double the lookback window (e.g., from 1 week to 2 weeks) or extend the prediction horizon to 24 hours.
#
# After each change:
# - Retrain your model.
# - Use `evaluate_on_test(...)` to visualize the extended 2-week prediction.
# - Compare validation and test MAE/RMSE across experiments.
# - Answer the graded questions.
#
# > *Note:* You’ll need to adjust the data-preparation cell above to rebuild the training, validation, and testing sets with the new parameters.

# %%
# Your code here, add as many cells as you like

lookback = 7 * 24
horizon = 3

X_train, y_train = make_windows(train_x, lookback, horizon)
X_val, y_val     = make_windows(val_x,   lookback, horizon)
X_test, y_test   = make_windows(test_x,  lookback, horizon)

model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32),
    Dropout(0.2),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

train_and_test(model,title="LB = 1 Week, H = 3hr",verbose=1)
# Out:
# LB = 1 Week, H = 3hr
#
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.7343 - mae: 0.7024 - rmse: 0.8557 - val_loss: 0.4279 - val_mae: 0.5539 - val_rmse: 0.6541
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4723 - mae: 0.5839 - rmse: 0.6871 - val_loss: 0.4055 - val_mae: 0.5395 - val_rmse: 0.6368
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4314 - mae: 0.5597 - rmse: 0.6567 - val_loss: 0.3815 - val_mae: 0.5237 - val_rmse: 0.6176
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3952 - mae: 0.5318 - rmse: 0.6286 - val_loss: 0.3368 - val_mae: 0.4953 - val_rmse: 0.5803
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3588 - mae: 0.5071 - rmse: 0.5989 - val_loss: 0.2971 - val_mae: 0.4653 - val_rmse: 0.5451
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3204 - mae: 0.4749 - rmse: 0.5660 - val_loss: 0.2560 - val_mae: 0.4309 - val_rmse: 0.5059
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2709 - mae: 0.4302 - rmse: 0.5204 - val_loss: 0.2172 - val_mae: 0.3907 - val_rmse: 0.4661
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2287 - mae: 0.3866 - rmse: 0.4782 - val_loss: 0.1850 - val_mae: 0.3570 - val_rmse: 0.4301
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2066 - mae: 0.3610 - rmse: 0.4545 - val_loss: 0.1896 - val_mae: 0.3543 - val_rmse: 0.4354
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1850 - mae: 0.3433 - rmse: 0.4302 - val_loss: 0.1629 - val_mae: 0.3267 - val_rmse: 0.4036
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1764 - mae: 0.3319 - rmse: 0.4199 - val_loss: 0.1523 - val_mae: 0.3140 - val_rmse: 0.3903
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 32.
# Selected epoch: 32 (min val_loss)
# Valid @ sel —  MAE: 0.1599 | RMSE: 0.2205 (scaled)
# Train @ sel —  MAE: 0.1822  | RMSE: 0.2364 (scaled)

# %%
evaluate_on_test(model)
# Out:
# Test RMSE (avg over all steps): 0.199 (scaled)
# Test  MAE (avg over all steps): 0.149 (scaled)
# Per-horizon (0 = 1-step ahead):
#   MAE : [0.09  0.156 0.202]
#   RMSE: [0.113 0.194 0.262]

# %%
lookback = 14 * 24
horizon = 12

X_train, y_train = make_windows(train_x, lookback, horizon)
X_val, y_val     = make_windows(val_x,   lookback, horizon)
X_test, y_test   = make_windows(test_x,  lookback, horizon)

model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32),
    Dropout(0.2),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

train_and_test(model,title="LB = 2 Week, H = 12hr",verbose=1)
# Out:
# LB = 2 Week, H = 12hr
#
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.9307 - mae: 0.7966 - rmse: 0.9639 - val_loss: 0.7392 - val_mae: 0.6963 - val_rmse: 0.8598
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6410 - mae: 0.6543 - rmse: 0.8004 - val_loss: 0.5889 - val_mae: 0.6268 - val_rmse: 0.7674
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5409 - mae: 0.6085 - rmse: 0.7354 - val_loss: 0.5022 - val_mae: 0.5817 - val_rmse: 0.7087
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4910 - mae: 0.5835 - rmse: 0.7007 - val_loss: 0.4551 - val_mae: 0.5573 - val_rmse: 0.6746
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4438 - mae: 0.5569 - rmse: 0.6661 - val_loss: 0.4372 - val_mae: 0.5493 - val_rmse: 0.6612
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4032 - mae: 0.5298 - rmse: 0.6350 - val_loss: 0.4367 - val_mae: 0.5483 - val_rmse: 0.6608
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3823 - mae: 0.5136 - rmse: 0.6183 - val_loss: 0.4338 - val_mae: 0.5472 - val_rmse: 0.6586
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3638 - mae: 0.5007 - rmse: 0.6031 - val_loss: 0.4361 - val_mae: 0.5476 - val_rmse: 0.6604
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3438 - mae: 0.4859 - rmse: 0.5863 - val_loss: 0.4290 - val_mae: 0.5448 - val_rmse: 0.6550
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3293 - mae: 0.4752 - rmse: 0.5738 - val_loss: 0.4280 - val_mae: 0.5428 - val_rmse: 0.6543
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3177 - mae: 0.4651 - rmse: 0.5636 - val_loss: 0.4136 - val_mae: 0.5368 - val_rmse: 0.6431
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3011 - mae: 0.4519 - rmse: 0.5487 - val_loss: 0.3916 - val_mae: 0.5223 - val_rmse: 0.6258
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2908 - mae: 0.4424 - rmse: 0.5392 - val_loss: 0.3719 - val_mae: 0.5101 - val_rmse: 0.6099
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2756 - mae: 0.4303 - rmse: 0.5250 - val_loss: 0.3540 - val_mae: 0.4971 - val_rmse: 0.5950
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2663 - mae: 0.4212 - rmse: 0.5160 - val_loss: 0.3240 - val_mae: 0.4734 - val_rmse: 0.5692
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2584 - mae: 0.4113 - rmse: 0.5083 - val_loss: 0.2731 - val_mae: 0.4320 - val_rmse: 0.5226
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2423 - mae: 0.3953 - rmse: 0.4922 - val_loss: 0.2217 - val_mae: 0.3910 - val_rmse: 0.4709
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2229 - mae: 0.3754 - rmse: 0.4721 - val_loss: 0.2140 - val_mae: 0.3847 - val_rmse: 0.4626
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2129 - mae: 0.3682 - rmse: 0.4614 - val_loss: 0.1970 - val_mae: 0.3697 - val_rmse: 0.4439
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2022 - mae: 0.3572 - rmse: 0.4497 - val_loss: 0.1822 - val_mae: 0.3623 - val_rmse: 0.4269
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1763 - mae: 0.3325 - rmse: 0.4199 - val_loss: 0.1663 - val_mae: 0.3435 - val_rmse: 0.4078
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1797 - mae: 0.3365 - rmse: 0.4239 - val_loss: 0.1626 - val_mae: 0.3384 - val_rmse: 0.4032
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1754 - mae: 0.3320 - rmse: 0.4188 - val_loss: 0.1568 - val_mae: 0.3309 - val_rmse: 0.3959
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1750 - mae: 0.3330 - rmse: 0.4183 - val_loss: 0.1798 - val_mae: 0.3589 - val_rmse: 0.4241
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1681 - mae: 0.3260 - rmse: 0.4099 - val_loss: 0.1552 - val_mae: 0.3297 - val_rmse: 0.3940
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1670 - mae: 0.3241 - rmse: 0.4087 - val_loss: 0.1647 - val_mae: 0.3423 - val_rmse: 0.4059
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1604 - mae: 0.3186 - rmse: 0.4005 - val_loss: 0.1633 - val_mae: 0.3401 - val_rmse: 0.4041
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1631 - mae: 0.3226 - rmse: 0.4038 - val_loss: 0.1591 - val_mae: 0.3353 - val_rmse: 0.3989
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1599 - mae: 0.3178 - rmse: 0.3998 - val_loss: 0.1622 - val_mae: 0.3389 - val_rmse: 0.4027
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1598 - mae: 0.3185 - rmse: 0.3997 - val_loss: 0.1637 - val_mae: 0.3409 - val_rmse: 0.4046
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 32.
# Selected epoch: 32 (min val_loss)
# Valid @ sel —  MAE: 0.3297 | RMSE: 0.394 (scaled)
# Train @ sel —  MAE: 0.3228  | RMSE: 0.4055 (scaled)

# %%
evaluate_on_test(model)
# Out:
# Test RMSE (avg over all steps): 0.520 (scaled)
# Test  MAE (avg over all steps): 0.421 (scaled)
# Per-horizon (0 = 1-step ahead):
#   MAE : [0.284 0.383 0.416 0.447 0.445 0.412 0.471 0.452 0.43  0.453 0.442 0.439
#  0.444 0.448 0.446 0.459 0.433 0.409 0.413 0.427 0.4   0.37  0.374 0.412]
#   RMSE: [0.366 0.465 0.516 0.544 0.541 0.498 0.568 0.561 0.515 0.542 0.542 0.53
#  0.529 0.544 0.54  0.553 0.537 0.516 0.514 0.536 0.51  0.474 0.474 0.514]

# %%
lookback = 14 * 24
horizon = 1

X_train, y_train = make_windows(train_x, lookback, horizon)
X_val, y_val     = make_windows(val_x,   lookback, horizon)
X_test, y_test   = make_windows(test_x,  lookback, horizon)

model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32),
    Dropout(0.2),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

train_and_test(model,title="LB = 2 Week, H = 1hr",verbose=1)
# Out:
# LB = 2 Week, H = 1hr
#
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.6572 - mae: 0.6624 - rmse: 0.8088 - val_loss: 0.3312 - val_mae: 0.4618 - val_rmse: 0.5755
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3668 - mae: 0.5129 - rmse: 0.6053 - val_loss: 0.2575 - val_mae: 0.4119 - val_rmse: 0.5075
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2798 - mae: 0.4496 - rmse: 0.5286 - val_loss: 0.1889 - val_mae: 0.3499 - val_rmse: 0.4347
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2025 - mae: 0.3782 - rmse: 0.4497 - val_loss: 0.1265 - val_mae: 0.2920 - val_rmse: 0.3557
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1331 - mae: 0.3019 - rmse: 0.3647 - val_loss: 0.0920 - val_mae: 0.2565 - val_rmse: 0.3034
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0964 - mae: 0.2489 - rmse: 0.3105 - val_loss: 0.0662 - val_mae: 0.2168 - val_rmse: 0.2573
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0755 - mae: 0.2220 - rmse: 0.2748 - val_loss: 0.0552 - val_mae: 0.1943 - val_rmse: 0.2349
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0649 - mae: 0.2061 - rmse: 0.2547 - val_loss: 0.0422 - val_mae: 0.1664 - val_rmse: 0.2054
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1658 - mae: 0.3226 - rmse: 0.4071 - val_loss: 0.1957 - val_mae: 0.3645 - val_rmse: 0.4424
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1621 - mae: 0.3198 - rmse: 0.4026 - val_loss: 0.1879 - val_mae: 0.3588 - val_rmse: 0.4335
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1627 - mae: 0.3213 - rmse: 0.4033 - val_loss: 0.1864 - val_mae: 0.3557 - val_rmse: 0.4317
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1542 - mae: 0.3116 - rmse: 0.3927 - val_loss: 0.1878 - val_mae: 0.3595 - val_rmse: 0.4334
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1523 - mae: 0.3098 - rmse: 0.3902 - val_loss: 0.1913 - val_mae: 0.3592 - val_rmse: 0.4374
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1518 - mae: 0.3084 - rmse: 0.3896 - val_loss: 0.2021 - val_mae: 0.3738 - val_rmse: 0.4496
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1470 - mae: 0.3036 - rmse: 0.3834 - val_loss: 0.1856 - val_mae: 0.3576 - val_rmse: 0.4308
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1471 - mae: 0.3033 - rmse: 0.3835 - val_loss: 0.1924 - val_mae: 0.3644 - val_rmse: 0.4387
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1426 - mae: 0.2993 - rmse: 0.3776 - val_loss: 0.1942 - val_mae: 0.3660 - val_rmse: 0.4407
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1471 - mae: 0.3024 - rmse: 0.3836 - val_loss: 0.1885 - val_mae: 0.3603 - val_rmse: 0.4342
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1439 - mae: 0.3004 - rmse: 0.3793 - val_loss: 0.1967 - val_mae: 0.3669 - val_rmse: 0.4435
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1431 - mae: 0.2990 - rmse: 0.3782 - val_loss: 0.1982 - val_mae: 0.3691 - val_rmse: 0.4452
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 34.
# Selected epoch: 34 (min val_loss)
# Valid @ sel —  MAE: 0.3576 | RMSE: 0.4308 (scaled)
# Train @ sel —  MAE: 0.3045  | RMSE: 0.3845 (scaled)

# %%
evaluate_on_test(model)
# Out:
# Test RMSE (avg over all steps): 0.466 (scaled)
# Test  MAE (avg over all steps): 0.376 (scaled)
# Per-horizon (0 = 1-step ahead):
#   MAE : [0.218 0.262 0.34  0.37  0.404 0.427 0.421 0.422 0.424 0.408 0.41  0.414
#  0.423 0.436 0.415 0.425 0.372 0.392 0.371 0.354 0.329 0.321 0.328 0.337]
#   RMSE: [0.283 0.337 0.415 0.456 0.485 0.511 0.502 0.496 0.495 0.486 0.493 0.497
#  0.509 0.516 0.504 0.534 0.477 0.499 0.483 0.45  0.425 0.41  0.412 0.42 ]

# %%
print_results()
# Out:
# Baseline Model                       val_RMSE@min_val_loss=0.1352 | val_MAE@min_val_loss=0.09935 | epoch=19  (scaled)
# LB = 2 Week, H = 1hr                 val_RMSE@min_val_loss=0.1539 | val_MAE@min_val_loss=0.0997 | epoch=22  (scaled)
# LB = 1 Week, H = 3hr                 val_RMSE@min_val_loss=0.2205 | val_MAE@min_val_loss=0.1599 | epoch=32  (scaled)
# LB = 2 Week, H = 24hr                val_RMSE@min_val_loss=0.394 | val_MAE@min_val_loss=0.3297 | epoch=32  (scaled)
# LB = 2 Week, H = 12hr                val_RMSE@min_val_loss=0.4072 | val_MAE@min_val_loss=0.3417 | epoch=32  (scaled)
# LB = 1 Week, H = 24hr                val_RMSE@min_val_loss=0.4308 | val_MAE@min_val_loss=0.3576 | epoch=34  (scaled)
# LB = 2 Weeks, H = 24hr               val_RMSE@min_val_loss=0.6262 | val_MAE@min_val_loss=0.5308 | epoch=8  (scaled)

# %% [markdown]
# ### Graded Questions

# %%
# Set a1 to the Validation MAE at the epoch of minimum validation loss (mse) for your best choices of lookback and horizon

a1a = 0.0997             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a1a = {a1a:.4f}')
# Out:
# a1a = 0.0997

# %% [markdown]
# #### Question a1b: Describe below your experiments. What effect did your changes to the lookback and horizon have? Did you get an improvement in the validation MAE?
#
# #### Your Answer Here:

# %% [markdown]
# An improvement over the baseline model for validation MAE was not achieved, though the best performing experiment obtained essentially an identical result. The experiments varied horizon times ranging from 1 hr to 24 hrs, and lookbacks ranged from 1 to 2 weeks. The best performing experiment was a lookback of 2 weeks and a horizon of 1 hr, which was an extension of 1 week to the baseline lookback with the same baseline horizon. In isolation, increasing the lookback tends to improve performance as the model is able to train off of more data, but only up to a point (as seen here, there was no improvement). Needlessly increasing lookback can result in overfitting. Increasing the horizon tended to increase MAE as predicting more future steps at once is more difficult as uncertainty compounds over time.

# %% [markdown]
# ## Problem Two — Architectural Tweaks
#
# Using the best lookback and horizon from Problem 1 (or the original defaults if they performed better),
# experiment with at least **one architectural change**.
#
# Possible options:
# - Add a deeper “head” (e.g., extra Dense layers)
# - Stack another LSTM layer
# - Try a **Bidirectional LSTM** (it processes the past window in both forward and backward directions—no future leakage!)
#
# Train, evaluate, and answer the graded questions.

# %%
# Your code here, add as many cells as you like

lookback = 7 * 24
horizon = 1

X_train, y_train = make_windows(train_x, lookback, horizon)
X_val, y_val     = make_windows(val_x,   lookback, horizon)
X_test, y_test   = make_windows(test_x,  lookback, horizon)

model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32),
    Dropout(0.2),
    Dense(32, activation="relu", kernel_initializer=hn),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

train_and_test(model,title="LB = 1 Week, H = 1hr, Deeper Head",verbose=1)
# Out:
# LB = 1 Week, H = 1hr, Deeper Head
#
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.6608 - mae: 0.6564 - rmse: 0.8075 - val_loss: 0.3364 - val_mae: 0.4948 - val_rmse: 0.5800
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3178 - mae: 0.4805 - rmse: 0.5633 - val_loss: 0.2655 - val_mae: 0.4327 - val_rmse: 0.5153
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2395 - mae: 0.4142 - rmse: 0.4888 - val_loss: 0.1738 - val_mae: 0.3459 - val_rmse: 0.4169
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1713 - mae: 0.3403 - rmse: 0.4133 - val_loss: 0.1046 - val_mae: 0.2725 - val_rmse: 0.3235
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1120 - mae: 0.2709 - rmse: 0.3345 - val_loss: 0.0956 - val_mae: 0.2607 - val_rmse: 0.3092
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0884 - mae: 0.2386 - rmse: 0.2970 - val_loss: 0.0586 - val_mae: 0.2054 - val_rmse: 0.2421
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0681 - mae: 0.2065 - rmse: 0.2607 - val_loss: 0.0495 - val_mae: 0.1840 - val_rmse: 0.2224
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0576 - mae: 0.1901 - rmse: 0.2399 - val_loss: 0.0377 - val_mae: 0.1555 - val_rmse: 0.1941
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0496 - mae: 0.1795 - rmse: 0.2227 - val_loss: 0.0336 - val_mae: 0.1469 - val_rmse: 0.1833
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0428 - mae: 0.1642 - rmse: 0.2069 - val_loss: 0.0289 - val_mae: 0.1320 - val_rmse: 0.1700
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0378 - mae: 0.1522 - rmse: 0.1944 - val_loss: 0.0235 - val_mae: 0.1172 - val_rmse: 0.1534
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0353 - mae: 0.1466 - rmse: 0.1878 - val_loss: 0.0275 - val_mae: 0.1236 - val_rmse: 0.1657
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0332 - mae: 0.1405 - rmse: 0.1822 - val_loss: 0.0209 - val_mae: 0.1066 - val_rmse: 0.1447
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0299 - mae: 0.1370 - rmse: 0.1729 - val_loss: 0.0208 - val_mae: 0.1048 - val_rmse: 0.1441
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0281 - mae: 0.1311 - rmse: 0.1675 - val_loss: 0.0249 - val_mae: 0.1152 - val_rmse: 0.1579
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0273 - mae: 0.1295 - rmse: 0.1651 - val_loss: 0.0228 - val_mae: 0.1068 - val_rmse: 0.1511
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0248 - mae: 0.1220 - rmse: 0.1575 - val_loss: 0.0189 - val_mae: 0.0934 - val_rmse: 0.1374
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0256 - mae: 0.1241 - rmse: 0.1599 - val_loss: 0.0353 - val_mae: 0.1456 - val_rmse: 0.1880
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0227 - mae: 0.1193 - rmse: 0.1505 - val_loss: 0.0189 - val_mae: 0.0963 - val_rmse: 0.1374
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0228 - mae: 0.1196 - rmse: 0.1509 - val_loss: 0.0216 - val_mae: 0.1040 - val_rmse: 0.1469
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0220 - mae: 0.1151 - rmse: 0.1482 - val_loss: 0.0257 - val_mae: 0.1171 - val_rmse: 0.1603
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0207 - mae: 0.1132 - rmse: 0.1438 - val_loss: 0.0178 - val_mae: 0.0910 - val_rmse: 0.1334
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0207 - mae: 0.1112 - rmse: 0.1437 - val_loss: 0.0249 - val_mae: 0.1133 - val_rmse: 0.1577
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0198 - mae: 0.1107 - rmse: 0.1407 - val_loss: 0.0291 - val_mae: 0.1291 - val_rmse: 0.1706
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0181 - mae: 0.1038 - rmse: 0.1344 - val_loss: 0.0248 - val_mae: 0.1134 - val_rmse: 0.1573
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0195 - mae: 0.1076 - rmse: 0.1395 - val_loss: 0.0157 - val_mae: 0.0815 - val_rmse: 0.1254
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0193 - mae: 0.1073 - rmse: 0.1387 - val_loss: 0.0171 - val_mae: 0.0873 - val_rmse: 0.1307
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0185 - mae: 0.1059 - rmse: 0.1362 - val_loss: 0.0260 - val_mae: 0.1181 - val_rmse: 0.1614
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0189 - mae: 0.1063 - rmse: 0.1375 - val_loss: 0.0230 - val_mae: 0.1075 - val_rmse: 0.1517
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0173 - mae: 0.1027 - rmse: 0.1316 - val_loss: 0.0219 - val_mae: 0.1033 - val_rmse: 0.1480
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0181 - mae: 0.1042 - rmse: 0.1345 - val_loss: 0.0188 - val_mae: 0.0900 - val_rmse: 0.1372
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 26.
# Selected epoch: 26 (min val_loss)
# Valid @ sel —  MAE: 0.0815 | RMSE: 0.1254 (scaled)
# Train @ sel —  MAE: 0.1077  | RMSE: 0.139 (scaled)

# %%
evaluate_on_test(model)
# Out:
# Test RMSE (avg over all steps): 0.086 (scaled)
# Test  MAE (avg over all steps): 0.067 (scaled)

# %%
print_results()
# Out:
# LB = 1 Week, H = 1hr, Deeper Head    val_RMSE@min_val_loss=0.1254 | val_MAE@min_val_loss=0.0815 | epoch=26  (scaled)
# Baseline Model                       val_RMSE@min_val_loss=0.1352 | val_MAE@min_val_loss=0.09935 | epoch=19  (scaled)
# LB = 1 Week, H = 24hr, Deeper Head   val_RMSE@min_val_loss=0.1425 | val_MAE@min_val_loss=0.09593 | epoch=25  (scaled)
# LB = 2 Week, H = 1hr                 val_RMSE@min_val_loss=0.1539 | val_MAE@min_val_loss=0.0997 | epoch=22  (scaled)
# LB = 1 Week, H = 3hr                 val_RMSE@min_val_loss=0.2205 | val_MAE@min_val_loss=0.1599 | epoch=32  (scaled)
# LB = 2 Week, H = 24hr                val_RMSE@min_val_loss=0.394 | val_MAE@min_val_loss=0.3297 | epoch=32  (scaled)
# LB = 2 Week, H = 12hr                val_RMSE@min_val_loss=0.4072 | val_MAE@min_val_loss=0.3417 | epoch=32  (scaled)
# LB = 1 Week, H = 24hr                val_RMSE@min_val_loss=0.4308 | val_MAE@min_val_loss=0.3576 | epoch=34  (scaled)
# LB = 2 Weeks, H = 24hr               val_RMSE@min_val_loss=0.6262 | val_MAE@min_val_loss=0.5308 | epoch=8  (scaled)

# %% [markdown]
# ### Graded Questions

# %%
# Set a1 to the Validation MAE at the epoch of minimum validation loss (mse)

a2a = 0.0815             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a2a = {a2a:.4f}')
# Out:
# a2a = 0.0815

# %% [markdown]
# #### Question a2b: Describe below your experiments and what you observed. Did you get a better validation MAE through architectural changes?
#
# #### Your Answer Here:

# %% [markdown]
# Adding an additional dense layer did improve the model over the baseline, bringing the MAE down to 0.0815. The LSTM extracted the temporal patterns in the data, and the dense layers interpret these patterns. The extra dense layer added nonlinear capacity to map the features to accurate predictions and reduced underfitting by capturing more complex relationships.

# %% [markdown]
# ## Problem Three — Autoregressive Forecasting (ChatGPT Discussion)
#
# In this final problem, you’ll explore **autoregressive forecasting**, where the model predicts one step ahead and feeds that prediction back as input to generate the next step.
#
# **Your task:**
# 1. Briefly describe your current model to ChatGPT (e.g., “My LSTM predicts the next 24 hours directly from the past 168 hours.”), or share a short code snippet.
# 2. Ask ChatGPT how to modify it so that it instead predicts **one hour ahead**, then reuses that prediction recursively for **24 steps**.
# 3. Implement or outline the version it suggests.
# 4. Answer the graded question.

# %%
# Your code here, add as many cells as you like

def autoregressive_forecast(model, initial_window, steps=24, scaler=None):
    window = initial_window.copy().reshape(1, lookback, 1)
    preds = []

    for _ in range(steps):
        # predict next hour
        next_scaled = model.predict(window, verbose=0)[0, 0]
        preds.append(next_scaled)

        # shift window and append new prediction
        new_series = np.append(window[0, :, 0], next_scaled)[-lookback:]
        window = new_series.reshape(1, lookback, 1)

    preds = np.array(preds)

    if scaler is not None:
        preds = scaler.inverse_transform(preds.reshape(-1,1)).ravel()

    return preds

# %%
seed = test_x[-lookback:]
pred_24 = autoregressive_forecast(model, seed, steps=24, scaler=scaler)

# %%
true_24 = s6.iloc[-24:]                # last 24 true hours
pred_series = pd.Series(pred_24, index=true_24.index)

plt.figure(figsize=(12,5))
plt.plot(true_24, label="True Load")
plt.plot(pred_series, label="Autoregressive Forecast", linestyle="--")
plt.title("Autoregressive 24-Hour Forecast (1-Step Model)")
plt.ylabel("MW")
plt.grid(True, linestyle=":")
plt.legend()
plt.show()

# %% [markdown]
# ### Graded Questions

# %% [markdown]
# #### Question a3: Answer the graded questions comparing the recursive and direct approaches:
#    - Does the error grow with horizon in the autoregressive version?
#    - Which approach you tried in this homework performs better overall?
#
# #### Your Answer Here:

# %% [markdown]
# The error does seem to grow with horizon over the 24 steps in the autoregressive model. This makes sense as each step after the first is reliant on the previously predicted values, not true values. Therefore, small errors in early steps become inputs to later predictions, compounding over time and creating drift. The best performing model in this homework was the baseline setting of lookback = 1 week and horizon = 1 hour with an additional dense layer. This was able to reduce the baseline validation MAE of 0.09935 to 0.0815(nearly 20% reduction) as the additional layer was able to better capture feature relationships, resulting in better generaliation.

# %%
print_results()
# Out:
# LB = 1 Week, H = 1hr, Deeper Head    val_RMSE@min_val_loss=0.1254 | val_MAE@min_val_loss=0.0815 | epoch=26  (scaled)
# Baseline Model                       val_RMSE@min_val_loss=0.1352 | val_MAE@min_val_loss=0.09935 | epoch=19  (scaled)
# LB = 1 Week, H = 24hr, Deeper Head   val_RMSE@min_val_loss=0.1425 | val_MAE@min_val_loss=0.09593 | epoch=25  (scaled)
# LB = 2 Week, H = 1hr                 val_RMSE@min_val_loss=0.1539 | val_MAE@min_val_loss=0.0997 | epoch=22  (scaled)
# LB = 1 Week, H = 3hr                 val_RMSE@min_val_loss=0.2205 | val_MAE@min_val_loss=0.1599 | epoch=32  (scaled)
# LB = 2 Week, H = 24hr                val_RMSE@min_val_loss=0.394 | val_MAE@min_val_loss=0.3297 | epoch=32  (scaled)
# LB = 2 Week, H = 12hr                val_RMSE@min_val_loss=0.4072 | val_MAE@min_val_loss=0.3417 | epoch=32  (scaled)
# LB = 1 Week, H = 24hr                val_RMSE@min_val_loss=0.4308 | val_MAE@min_val_loss=0.3576 | epoch=34  (scaled)
# LB = 2 Weeks, H = 24hr               val_RMSE@min_val_loss=0.6262 | val_MAE@min_val_loss=0.5308 | epoch=8  (scaled)
